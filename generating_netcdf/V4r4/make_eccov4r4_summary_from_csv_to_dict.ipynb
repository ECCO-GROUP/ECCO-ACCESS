# %%
import argparse
import dask
import json
import netCDF4 as nc4
import numpy as np
import pandas as pd
from pathlib import Path
from pprint import pprint
import time
import warnings
import xarray as xr
from dask import delayed
import datetime
import random
from pandas import read_csv

warnings.filterwarnings('ignore')

# %%
ecco_V4r4_metadata_dir = Path('/home/ifenty/git_repos_others/ECCO-GROUP/ECCO-ACCESS/metadata/ECCOv4r4_metadata_json')
dataset_metadata_fname = ecco_V4r4_metadata_dir / 'PODAAC_datasets-revised_20210226.5.csv'

# %%
# load PODAAC fields
podaac_dataset_table = read_csv(dataset_metadata_fname)

# %%
pprint(podaac_dataset_table['DATASET.PERSISTENT_ID'])
# Out:
# 0     PODAAC-ECG5D-ATM44
# 1     PODAAC-ECG5M-ATM44
# 2     PODAAC-ECL5D-ATM44
# 3     PODAAC-ECL5M-ATM44
# 4     PODAAC-ECG5D-BOL44
#              ...
# 74    PODAAC-ECL5S-OTS44
# 75    PODAAC-ECL5A-GRD44
# 76    PODAAC-ECG5A-GRD44
# 77    PODAAC-ECL5A-MIX44
# 78    PODAAC-ECG5A-MIX44
# Name: DATASET.PERSISTENT_ID, Length: 79, dtype: object

# %%
ds_id = list()
for id in list(podaac_dataset_table['DATASET.PERSISTENT_ID']):
    ds_id.append(id.split('PODAAC-')[1])
pprint(ds_id)
# Out:
# ['ECG5D-ATM44',
#  'ECG5M-ATM44',
#  'ECL5D-ATM44',
#  'ECL5M-ATM44',
#  'ECG5D-BOL44',
#  'ECG5M-BOL44',
#  'ECL5D-BOL44',
#  'ECL5M-BOL44',
#  'ECG5D-ODE44',
#  'ECG5M-ODE44',
#  'ECL5D-ODE44',
#  'ECL5M-ODE44',
#  'ECG5D-FRE44',
#  'ECG5M-FRE44',
#  'ECL5D-FRE44',
#  'ECL5M-FRE44',
#  'ECTSS-MAP44',
#  'ECTSD-MSL44',
#  'ECTSM-MSL44',
#  'ECG5D-HEA44',
#  'ECG5M-HEA44',
#  'ECL5D-HEA44',
#  'ECL5M-HEA44',
#  'ECG5D-OML44',
#  'ECG5M-OML44',
#  'ECL5D-OML44',
#  'ECL5M-OML44',
#  'ECG5D-OBP44',
#  'ECG5M-OBP44',
#  'ECL5D-OBP44',
#  'ECL5M-OBP44',
#  'ECL5S-OBP44',
#  'ECL5D-3MT44',
#  'ECL5M-3MT44',
#  'ECL5D-3SF44',
#  'ECL5M-3SF44',
#  'ECL5D-3TF44',
#  'ECL5M-3TF44',
#  'ECL5D-3VF44',
#  'ECL5M-3VF44',
#  'ECL5D-STF44',
#  'ECL5M-STF44',
#  'ECG5D-OVE44',
#  'ECG5M-OVE44',
#  'ECL5D-OVE44',
#  'ECL5M-OVE44',
#  'ECTSS-SBO44',
#  'ECG5D-ICO44',
#  'ECG5M-ICO44',
#  'ECL5D-ICO44',
#  'ECL5M-ICO44',
#  'ECL5S-ICO44',
#  'ECL5D-SIH44',
#  'ECL5M-SIH44',
#  'ECL5D-ISP44',
#  'ECL5M-ISP44',
#  'ECG5D-SIV44',
#  'ECG5M-SIV44',
#  'ECL5D-SIV44',
#  'ECL5M-SIV44',
#  'ECL5S-SIV44',
#  'ECG5D-SSH44',
#  'ECG5M-SSH44',
#  'ECL5D-SSH44',
#  'ECL5M-SSH44',
#  'ECL5S-SSH44',
#  'ECG5D-STR44',
#  'ECG5M-STR44',
#  'ECL5D-STR44',
#  'ECL5M-STR44',
#  'ECG5D-OTS44',
#  'ECG5M-OTS44',
#  'ECL5D-OTS44',
#  'ECL5M-OTS44',
#  'ECL5S-OTS44',
#  'ECL5A-GRD44',
#  'ECG5A-GRD44',
#  'ECL5A-MIX44',
#  'ECG5A-MIX44']

# %%
ds_shortname = list(podaac_dataset_table['DATASET.SHORT_NAME'])

# %%
ds_summary = list(podaac_dataset_table['DATASET.DESCRIPTION'])

# %%
ds_title = list(podaac_dataset_table['DATASET.LONG_NAME'])

# %%
ds_fname = list(podaac_dataset_table['DATASET.FILENAME'])

# %%
summary_second_part = 'Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.'
print(summary_second_part)
# Out:
# Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.

# %%
ds_summary_fix = dict()
for idi, id in enumerate(ds_id):
    print(idi, id, ds_title[idi][0:75])
    ds_summary_fix[id] = dict()
    ds_summary_fix[id]['title'] = ds_title[idi]
    ds_summary_fix[id]['shortname'] = ds_shortname[idi]
    ds_summary_fix[id]['summary_first_part']= ds_summary[idi].split('Estimating the Circulation and Climate of the Ocean')[0]
    ds_summary_fix[id]['summary']= ds_summary_fix[id]['summary_first_part'] + summary_second_part
    ds_summary_fix[id]['filename'] = ds_fname[idi]
# Out:
# 0 ECG5D-ATM44 ECCO Atmosphere Surface Temperature, Humidity, Wind, and Pressure - Daily M
# 1 ECG5M-ATM44 ECCO Atmosphere Surface Temperature, Humidity, Wind, and Pressure - Monthly
# 2 ECL5D-ATM44 ECCO Atmosphere Surface Temperature, Humidity, Wind, and Pressure - Daily M
# 3 ECL5M-ATM44 ECCO Atmosphere Surface Temperature, Humidity, Wind, and Pressure - Monthly
# 4 ECG5D-BOL44 ECCO Gent-McWilliams Ocean Bolus Velocity - Daily Mean 0.5 Degree (Version
# 5 ECG5M-BOL44 ECCO Gent-McWilliams Ocean Bolus Velocity - Monthly Mean 0.5 Degree (Versio
# 6 ECL5D-BOL44 ECCO Gent-McWilliams Ocean Bolus Velocity - Daily Mean llc90 Grid (Version
# 7 ECL5M-BOL44 ECCO Gent-McWilliams Ocean Bolus Velocity - Monthly Mean llc90 Grid (Versio
# 8 ECG5D-ODE44 ECCO Ocean Density, Stratification, and Hydrostatic Pressure - Daily Mean 0
# 9 ECG5M-ODE44 ECCO Ocean Density, Stratification, and Hydrostatic Pressure - Monthly Mean
# 10 ECL5D-ODE44 ECCO Ocean Density, Stratification, and Hydrostatic Pressure - Daily Mean l
# 11 ECL5M-ODE44 ECCO Ocean Density, Stratification, and Hydrostatic Pressure - Monthly Mean
# 12 ECG5D-FRE44 ECCO Ocean and Sea-Ice Surface Freshwater Fluxes - Daily Mean 0.5 Degree (V
# 13 ECG5M-FRE44 ECCO Ocean and Sea-Ice Surface Freshwater Fluxes - Monthly Mean 0.5 Degree
# 14 ECL5D-FRE44 ECCO Ocean and Sea-Ice Surface Freshwater Fluxes - Daily Mean llc90 Grid (V
# 15 ECL5M-FRE44 ECCO Ocean and Sea-Ice Surface Freshwater Fluxes - Monthly Mean llc90 Grid
# 16 ECTSS-MAP44 ECCO Global Mean Atmospheric Pressure - Snapshot (Version 4 Release 4)
# 17 ECTSD-MSL44 ECCO Global Mean Sea Level - Daily Mean (Version 4 Release 4)
# 18 ECTSM-MSL44 ECCO Global Mean Sea Level - Monthly Mean (Version 4 Release 4)
# 19 ECG5D-HEA44 ECCO Ocean and Sea-Ice Surface Heat Fluxes - Daily Mean 0.5 Degree (Version
# 20 ECG5M-HEA44 ECCO Ocean and Sea-Ice Surface Heat Fluxes - Monthly Mean 0.5 Degree (Versi
# 21 ECL5D-HEA44 ECCO Ocean and Sea-Ice Surface Heat Fluxes - Daily Mean llc90 Grid (Version
# 22 ECL5M-HEA44 ECCO Ocean and Sea-Ice Surface Heat Fluxes - Monthly Mean llc90 Grid (Versi
# 23 ECG5D-OML44 ECCO Ocean Mixed Layer Depth - Daily Mean 0.5 Degree (Version 4 Release 4)
# 24 ECG5M-OML44 ECCO Ocean Mixed Layer Depth - Monthly Mean 0.5 Degree (Version 4 Release 4
# 25 ECL5D-OML44 ECCO Ocean Mixed Layer Depth - Daily Mean llc90 Grid (Version 4 Release 4)
# 26 ECL5M-OML44 ECCO Ocean Mixed Layer Depth - Monthly Mean llc90 Grid (Version 4 Release 4
# 27 ECG5D-OBP44 ECCO Ocean Bottom Pressure - Daily Mean 0.5 Degree (Version 4 Release 4)
# 28 ECG5M-OBP44 ECCO Ocean Bottom Pressure - Monthly Mean 0.5 Degree (Version 4 Release 4)
# 29 ECL5D-OBP44 ECCO Ocean Bottom Pressure - Daily Mean llc90 Grid (Version 4 Release 4)
# 30 ECL5M-OBP44 ECCO Ocean Bottom Pressure - Monthly Mean llc90 Grid (Version 4 Release 4)
# 31 ECL5S-OBP44 ECCO Ocean Bottom Pressure - Snapshot llc90 Grid (Version 4 Release 4)
# 32 ECL5D-3MT44 ECCO Ocean Three-Dimensional Momentum Tendency - Daily Mean llc90 Grid (Ver
# 33 ECL5M-3MT44 ECCO Ocean Three-Dimensional Momentum Tendency - Monthly Mean llc90 Grid (V
# 34 ECL5D-3SF44 ECCO Ocean Three-Dimensional Salinity Fluxes - Daily Mean llc90 Grid (Versi
# 35 ECL5M-3SF44 ECCO Ocean Three-Dimensional Salinity Fluxes - Monthly Mean llc90 Grid (Ver
# 36 ECL5D-3TF44 ECCO Ocean Three-Dimensional Potential Temperature Fluxes - Daily Mean llc9
# 37 ECL5M-3TF44 ECCO Ocean Three-Dimensional Potential Temperature Fluxes - Monthly Mean ll
# 38 ECL5D-3VF44 ECCO Ocean Three-Dimensional Volume Fluxes - Daily Mean llc90 Grid (Version
# 39 ECL5M-3VF44 ECCO Ocean Three-Dimensional Volume Fluxes - Monthly Mean llc90 Grid (Versi
# 40 ECL5D-STF44 ECCO Gent-McWilliams Bolus Transport Streamfunction - Daily Mean llc90 Grid
# 41 ECL5M-STF44 ECCO Gent-McWilliams Bolus Transport Streamfunction - Monthly Mean llc90 Gr
# 42 ECG5D-OVE44 ECCO Ocean Velocity - Daily Mean 0.5 Degree (Version 4 Release 4)
# 43 ECG5M-OVE44 ECCO Ocean Velocity - Monthly Mean 0.5 Degree (Version 4 Release 4)
# 44 ECL5D-OVE44 ECCO Ocean Velocity - Daily Mean llc90 Grid (Version 4 Release 4)
# 45 ECL5M-OVE44 ECCO Ocean Velocity - Monthly Mean llc90 Grid (Version 4 Release 4)
# 46 ECTSS-SBO44 ECCO SBO Core Products - Snapshot (Version 4 Release 4)
# 47 ECG5D-ICO44 ECCO Sea-Ice and Snow Concentration and Thickness - Daily Mean 0.5 Degree (
# 48 ECG5M-ICO44 ECCO Sea-Ice and Snow Concentration and Thickness - Monthly Mean 0.5 Degree
# 49 ECL5D-ICO44 ECCO Sea-Ice and Snow Concentration and Thickness - Daily Mean llc90 Grid (
# 50 ECL5M-ICO44 ECCO Sea-Ice and Snow Concentration and Thickness - Monthly Mean llc90 Grid
# 51 ECL5S-ICO44 ECCO Sea-Ice and Snow Concentration and Thickness - Snapshot llc90 Grid (Ve
# 52 ECL5D-SIH44 ECCO Sea-Ice and Snow Horizontal Volume Fluxes - Daily Mean llc90 Grid (Ver
# 53 ECL5M-SIH44 ECCO Sea-Ice and Snow Horizontal Volume Fluxes - Monthly Mean llc90 Grid (V
# 54 ECL5D-ISP44 ECCO Sea-Ice Salt Plume Fluxes - Daily Mean llc90 Grid (Version 4 Release 4
# 55 ECL5M-ISP44 ECCO Sea-Ice Salt Plume Fluxes - Monthly Mean llc90 Grid (Version 4 Release
# 56 ECG5D-SIV44 ECCO Sea-Ice Velocity - Daily Mean 0.5 Degree (Version 4 Release 4)
# 57 ECG5M-SIV44 ECCO Sea-Ice Velocity - Monthly Mean 0.5 Degree (Version 4 Release 4)
# 58 ECL5D-SIV44 ECCO Sea-Ice Velocity - Daily Mean llc90 Grid (Version 4 Release 4)
# 59 ECL5M-SIV44 ECCO Sea-Ice Velocity - Monthly Mean llc90 Grid (Version 4 Release 4)
# 60 ECL5S-SIV44 ECCO Sea-Ice Velocity - Snapshot llc90 Grid (Version 4 Release 4)
# 61 ECG5D-SSH44 ECCO Sea Surface Height - Daily Mean 0.5 Degree (Version 4 Release 4)
# 62 ECG5M-SSH44 ECCO Sea Surface Height - Monthly Mean 0.5 Degree (Version 4 Release 4)
# 63 ECL5D-SSH44 ECCO Sea Surface Height - Daily Mean llc90 Grid (Version 4 Release 4)
# 64 ECL5M-SSH44 ECCO Sea Surface Height - Monthly Mean llc90 Grid (Version 4 Release 4)
# 65 ECL5S-SSH44 ECCO Sea Surface Height - Snapshot llc90 Grid (Version 4 Release 4)
# 66 ECG5D-STR44 ECCO Ocean and Sea-Ice Surface Stress - Daily Mean 0.5 Degree (Version 4 Re
# 67 ECG5M-STR44 ECCO Ocean and Sea-Ice Surface Stress - Monthly Mean 0.5 Degree (Version 4
# 68 ECL5D-STR44 ECCO Ocean and Sea-Ice Surface Stress - Daily Mean llc90 Grid (Version 4 Re
# 69 ECL5M-STR44 ECCO Ocean and Sea-Ice Surface Stress - Monthly Mean llc90 Grid (Version 4
# 70 ECG5D-OTS44 ECCO Ocean Temperature and Salinity - Daily Mean 0.5 Degree (Version 4 Rele
# 71 ECG5M-OTS44 ECCO Ocean Temperature and Salinity - Monthly Mean 0.5 Degree (Version 4 Re
# 72 ECL5D-OTS44 ECCO Ocean Temperature and Salinity - Daily Mean llc90 Grid (Version 4 Rele
# 73 ECL5M-OTS44 ECCO Ocean Temperature and Salinity - Monthly Mean llc90 Grid (Version 4 Re
# 74 ECL5S-OTS44 ECCO Ocean Temperature and Salinity - Snapshot llc90 Grid (Version 4 Releas
# 75 ECL5A-GRD44 ECCO Geometry Parameters for the Lat-Lon-Cap 90 (llc90) Native Model Grid (
# 76 ECG5A-GRD44 ECCO Geometry Parameters for the 0.5 degree Lat-Lon Model Grid (Version 4 R
# 77 ECL5A-MIX44 ECCO Ocean 3D Gent-Mcwilliams, Redi, and Background Vertical Diffusivity Co
# 78 ECG5A-MIX44 ECCO Ocean 3D Gent-Mcwilliams, Redi, and Background Vertical Diffusivity Co

# %%
ds_summary_fix[id]['summary_first_part']
# Out:
# 'This dataset provides 3D time-invariant coefficients for the Gent-McWilliams and Redi parameterizations and background vertical diffusivity interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. '

# %%
ds_summary_fix[id]['summary']
# Out:
# 'This dataset provides 3D time-invariant coefficients for the Gent-McWilliams and Redi parameterizations and background vertical diffusivity interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.'

# %%
for idi, id in enumerate(ds_summary_fix.keys()):
    print(f'\n{idi:02}: {id}')
    print('   ', ds_summary_fix[id]['shortname'])
    print('   ', ds_summary_fix[id]['title'])

    print('---------------------------------------------------------------------------------------------------')
    print(ds_summary_fix[id]['summary_first_part'], '\n')
# Out:
# 00: ECG5D-ATM44
#     ECCO_L4_ATM_STATE_05DEG_DAILY_V4R4
#     ECCO Atmosphere Surface Temperature, Humidity, Wind, and Pressure - Daily Mean 0.5 Degree (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged atmosphere surface temperature, humidity, wind, and pressure interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 01: ECG5M-ATM44
#     ECCO_L4_ATM_STATE_05DEG_MONTHLY_V4R4
#     ECCO Atmosphere Surface Temperature, Humidity, Wind, and Pressure - Monthly Mean 0.5 Degree (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged atmosphere surface temperature, humidity, wind, and pressure interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 02: ECL5D-ATM44
#     ECCO_L4_ATM_STATE_LLC0090GRID_DAILY_V4R4
#     ECCO Atmosphere Surface Temperature, Humidity, Wind, and Pressure - Daily Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged atmosphere surface temperature, humidity, winds, and pressure on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 03: ECL5M-ATM44
#     ECCO_L4_ATM_STATE_LLC0090GRID_MONTHLY_V4R4
#     ECCO Atmosphere Surface Temperature, Humidity, Wind, and Pressure - Monthly Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged atmosphere surface temperature, humidity, winds, and pressure on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 04: ECG5D-BOL44
#     ECCO_L4_BOLUS_05DEG_DAILY_V4R4
#     ECCO Gent-McWilliams Ocean Bolus Velocity - Daily Mean 0.5 Degree (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged Gent-McWilliams ocean bolus velocity interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 05: ECG5M-BOL44
#     ECCO_L4_BOLUS_05DEG_MONTHLY_V4R4
#     ECCO Gent-McWilliams Ocean Bolus Velocity - Monthly Mean 0.5 Degree (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged Gent-McWilliams ocean bolus velocity interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 06: ECL5D-BOL44
#     ECCO_L4_BOLUS_LLC0090GRID_DAILY_V4R4
#     ECCO Gent-McWilliams Ocean Bolus Velocity - Daily Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged Gent-McWilliams ocean bolus velocity on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 07: ECL5M-BOL44
#     ECCO_L4_BOLUS_LLC0090GRID_MONTHLY_V4R4
#     ECCO Gent-McWilliams Ocean Bolus Velocity - Monthly Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged Gent-McWilliams bolus ocean velocity on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 08: ECG5D-ODE44
#     ECCO_L4_DENS_STRAT_PRESS_05DEG_DAILY_V4R4
#     ECCO Ocean Density, Stratification, and Hydrostatic Pressure - Daily Mean 0.5 Degree (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged ocean density, stratification, and hydrostatic pressure interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 09: ECG5M-ODE44
#     ECCO_L4_DENS_STRAT_PRESS_05DEG_MONTHLY_V4R4
#     ECCO Ocean Density, Stratification, and Hydrostatic Pressure - Monthly Mean 0.5 Degree (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged ocean density, stratification, and hydrostatic pressure interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 10: ECL5D-ODE44
#     ECCO_L4_DENS_STRAT_PRESS_LLC0090GRID_DAILY_V4R4
#     ECCO Ocean Density, Stratification, and Hydrostatic Pressure - Daily Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged ocean density, stratification, and hydrostatic pressure on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 11: ECL5M-ODE44
#     ECCO_L4_DENS_STRAT_PRESS_LLC0090GRID_MONTHLY_V4R4
#     ECCO Ocean Density, Stratification, and Hydrostatic Pressure - Monthly Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged ocean density, stratification, and hydrostatic pressure on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 12: ECG5D-FRE44
#     ECCO_L4_FRESH_FLUX_05DEG_DAILY_V4R4
#     ECCO Ocean and Sea-Ice Surface Freshwater Fluxes - Daily Mean 0.5 Degree (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged ocean and sea-ice surface freshwater fluxes interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 13: ECG5M-FRE44
#     ECCO_L4_FRESH_FLUX_05DEG_MONTHLY_V4R4
#     ECCO Ocean and Sea-Ice Surface Freshwater Fluxes - Monthly Mean 0.5 Degree (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged ocean and sea-ice surface freshwater fluxes interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 14: ECL5D-FRE44
#     ECCO_L4_FRESH_FLUX_LLC0090GRID_DAILY_V4R4
#     ECCO Ocean and Sea-Ice Surface Freshwater Fluxes - Daily Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged ocean and sea-ice surface freshwater fluxes on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 15: ECL5M-FRE44
#     ECCO_L4_FRESH_FLUX_LLC0090GRID_MONTHLY_V4R4
#     ECCO Ocean and Sea-Ice Surface Freshwater Fluxes - Monthly Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged ocean and sea-ice surface freshwater fluxes on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 16: ECTSS-MAP44
#     ECCO_L4_GMAP_TIME_SERIES_SNAPSHOT_V4R4
#     ECCO Global Mean Atmospheric Pressure - Snapshot (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides instantaneous hourly global mean atmospheric surface pressure over the ocean and sea-ice from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 17: ECTSD-MSL44
#     ECCO_L4_GMSL_TIME_SERIES_DAILY_V4R4
#     ECCO Global Mean Sea Level - Daily Mean (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged global mean sea level anomalies including barystatic and sterodynamic terms from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 18: ECTSM-MSL44
#     ECCO_L4_GMSL_TIME_SERIES_MONTHLY_V4R4
#     ECCO Global Mean Sea Level - Monthly Mean (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged global mean sea level anomalies including barystatic and sterodynamic terms from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 19: ECG5D-HEA44
#     ECCO_L4_HEAT_FLUX_05DEG_DAILY_V4R4
#     ECCO Ocean and Sea-Ice Surface Heat Fluxes - Daily Mean 0.5 Degree (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged ocean and sea-ice surface heat fluxes interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 20: ECG5M-HEA44
#     ECCO_L4_HEAT_FLUX_05DEG_MONTHLY_V4R4
#     ECCO Ocean and Sea-Ice Surface Heat Fluxes - Monthly Mean 0.5 Degree (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged ocean and sea-ice surface heat fluxes interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 21: ECL5D-HEA44
#     ECCO_L4_HEAT_FLUX_LLC0090GRID_DAILY_V4R4
#     ECCO Ocean and Sea-Ice Surface Heat Fluxes - Daily Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged ocean and sea-ice surface heat fluxes on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 22: ECL5M-HEA44
#     ECCO_L4_HEAT_FLUX_LLC0090GRID_MONTHLY_V4R4
#     ECCO Ocean and Sea-Ice Surface Heat Fluxes - Monthly Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged ocean and sea-ice surface heat fluxes on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 23: ECG5D-OML44
#     ECCO_L4_MIXED_LAYER_DEPTH_05DEG_DAILY_V4R4
#     ECCO Ocean Mixed Layer Depth - Daily Mean 0.5 Degree (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged ocean mixed layer depth interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 24: ECG5M-OML44
#     ECCO_L4_MIXED_LAYER_DEPTH_05DEG_MONTHLY_V4R4
#     ECCO Ocean Mixed Layer Depth - Monthly Mean 0.5 Degree (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged ocean mixed layer depth interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 25: ECL5D-OML44
#     ECCO_L4_MIXED_LAYER_DEPTH_LLC0090GRID_DAILY_V4R4
#     ECCO Ocean Mixed Layer Depth - Daily Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged ocean mixed layer depth on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 26: ECL5M-OML44
#     ECCO_L4_MIXED_LAYER_DEPTH_LLC0090GRID_MONTHLY_V4R4
#     ECCO Ocean Mixed Layer Depth - Monthly Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged ocean mixed layer depth on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 27: ECG5D-OBP44
#     ECCO_L4_OBP_05DEG_DAILY_V4R4
#     ECCO Ocean Bottom Pressure - Daily Mean 0.5 Degree (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged ocean bottom pressure interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 28: ECG5M-OBP44
#     ECCO_L4_OBP_05DEG_MONTHLY_V4R4
#     ECCO Ocean Bottom Pressure - Monthly Mean 0.5 Degree (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged ocean bottom pressure interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 29: ECL5D-OBP44
#     ECCO_L4_OBP_LLC0090GRID_DAILY_V4R4
#     ECCO Ocean Bottom Pressure - Daily Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged ocean bottom pressure and model ocean bottom pressure anomaly on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 30: ECL5M-OBP44
#     ECCO_L4_OBP_LLC0090GRID_MONTHLY_V4R4
#     ECCO Ocean Bottom Pressure - Monthly Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged ocean bottom pressure and model ocean bottom pressure anomaly on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 31: ECL5S-OBP44
#     ECCO_L4_OBP_LLC0090GRID_SNAPSHOT_V4R4
#     ECCO Ocean Bottom Pressure - Snapshot llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides instantaneous ocean bottom pressure and model ocean bottom pressure anomaly on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 32: ECL5D-3MT44
#     ECCO_L4_OCEAN_3D_MOMENTUM_TEND_LLC0090GRID_DAILY_V4R4
#     ECCO Ocean Three-Dimensional Momentum Tendency - Daily Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged three-dimensional ocean momentum tendency on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 33: ECL5M-3MT44
#     ECCO_L4_OCEAN_3D_MOMENTUM_TEND_LLC0090GRID_MONTHLY_V4R4
#     ECCO Ocean Three-Dimensional Momentum Tendency - Monthly Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged three-dimensional ocean momentum tendency on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 34: ECL5D-3SF44
#     ECCO_L4_OCEAN_3D_SALINITY_FLUX_LLC0090GRID_DAILY_V4R4
#     ECCO Ocean Three-Dimensional Salinity Fluxes - Daily Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged three-dimensional ocean salinity fluxes on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 35: ECL5M-3SF44
#     ECCO_L4_OCEAN_3D_SALINITY_FLUX_LLC0090GRID_MONTHLY_V4R4
#     ECCO Ocean Three-Dimensional Salinity Fluxes - Monthly Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged three-dimensional ocean salinity fluxes on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 36: ECL5D-3TF44
#     ECCO_L4_OCEAN_3D_TEMPERATURE_FLUX_LLC0090GRID_DAILY_V4R4
#     ECCO Ocean Three-Dimensional Potential Temperature Fluxes - Daily Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged three-dimensional ocean potential temperature fluxes on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 37: ECL5M-3TF44
#     ECCO_L4_OCEAN_3D_TEMPERATURE_FLUX_LLC0090GRID_MONTHLY_V4R4
#     ECCO Ocean Three-Dimensional Potential Temperature Fluxes - Monthly Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged three-dimensional ocean potential temperature fluxes on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 38: ECL5D-3VF44
#     ECCO_L4_OCEAN_3D_VOLUME_FLUX_LLC0090GRID_DAILY_V4R4
#     ECCO Ocean Three-Dimensional Volume Fluxes - Daily Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged three-dimensional ocean volume fluxes on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 39: ECL5M-3VF44
#     ECCO_L4_OCEAN_3D_VOLUME_FLUX_LLC0090GRID_MONTHLY_V4R4
#     ECCO Ocean Three-Dimensional Volume Fluxes - Monthly Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged three-dimensional ocean volume fluxes on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 40: ECL5D-STF44
#     ECCO_L4_OCEAN_BOLUS_STREAMFUNCTION_LLC0090GRID_DAILY_V4R4
#     ECCO Gent-McWilliams Bolus Transport Streamfunction - Daily Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged Gent-McWilliams ocean bolus transport streamfunctions on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 41: ECL5M-STF44
#     ECCO_L4_OCEAN_BOLUS_STREAMFUNCTION_LLC0090GRID_MONTHLY_V4R4
#     ECCO Gent-McWilliams Bolus Transport Streamfunction - Monthly Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged Gent-McWilliams ocean bolus transport streamfunctions on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 42: ECG5D-OVE44
#     ECCO_L4_OCEAN_VEL_05DEG_DAILY_V4R4
#     ECCO Ocean Velocity - Daily Mean 0.5 Degree (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged ocean velocity interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 43: ECG5M-OVE44
#     ECCO_L4_OCEAN_VEL_05DEG_MONTHLY_V4R4
#     ECCO Ocean Velocity - Monthly Mean 0.5 Degree (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged ocean velocity interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 44: ECL5D-OVE44
#     ECCO_L4_OCEAN_VEL_LLC0090GRID_DAILY_V4R4
#     ECCO Ocean Velocity - Daily Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged ocean velocity on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 45: ECL5M-OVE44
#     ECCO_L4_OCEAN_VEL_LLC0090GRID_MONTHLY_V4R4
#     ECCO Ocean Velocity - Monthly Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged ocean velocity on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 46: ECTSS-SBO44
#     ECCO_L4_SBO_CORE_TIME_SERIES_SNAPSHOT_V4R4
#     ECCO SBO Core Products - Snapshot (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides instantaneous hourly core products of the IERS Special Bureau for the Oceans from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 47: ECG5D-ICO44
#     ECCO_L4_SEA_ICE_CONC_THICKNESS_05DEG_DAILY_V4R4
#     ECCO Sea-Ice and Snow Concentration and Thickness - Daily Mean 0.5 Degree (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged sea-ice and snow concentration and thickness interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 48: ECG5M-ICO44
#     ECCO_L4_SEA_ICE_CONC_THICKNESS_05DEG_MONTHLY_V4R4
#     ECCO Sea-Ice and Snow Concentration and Thickness - Monthly Mean 0.5 Degree (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged sea-ice and snow concentration and thickness interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 49: ECL5D-ICO44
#     ECCO_L4_SEA_ICE_CONC_THICKNESS_LLC0090GRID_DAILY_V4R4
#     ECCO Sea-Ice and Snow Concentration and Thickness - Daily Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged sea-ice and snow concentration, thickness, and pressure loading on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 50: ECL5M-ICO44
#     ECCO_L4_SEA_ICE_CONC_THICKNESS_LLC0090GRID_MONTHLY_V4R4
#     ECCO Sea-Ice and Snow Concentration and Thickness - Monthly Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged sea-ice and snow concentration, thickness, and pressure loading on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 51: ECL5S-ICO44
#     ECCO_L4_SEA_ICE_CONC_THICKNESS_LLC0090GRID_SNAPSHOT_V4R4
#     ECCO Sea-Ice and Snow Concentration and Thickness - Snapshot llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides instantaneous sea-ice and snow concentration, thickness, and pressure loading on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 52: ECL5D-SIH44
#     ECCO_L4_SEA_ICE_HORIZ_VOLUME_FLUX_LLC0090GRID_DAILY_V4R4
#     ECCO Sea-Ice and Snow Horizontal Volume Fluxes - Daily Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged sea-ice and snow horizontal volume fluxes on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 53: ECL5M-SIH44
#     ECCO_L4_SEA_ICE_HORIZ_VOLUME_FLUX_LLC0090GRID_MONTHLY_V4R4
#     ECCO Sea-Ice and Snow Horizontal Volume Fluxes - Monthly Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged sea-ice and snow horizontal volume fluxes on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 54: ECL5D-ISP44
#     ECCO_L4_SEA_ICE_SALT_PLUME_FLUX_LLC0090GRID_DAILY_V4R4
#     ECCO Sea-Ice Salt Plume Fluxes - Daily Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged sea-ice salt plume fluxes on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 55: ECL5M-ISP44
#     ECCO_L4_SEA_ICE_SALT_PLUME_FLUX_LLC0090GRID_MONTHLY_V4R4
#     ECCO Sea-Ice Salt Plume Fluxes - Monthly Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged sea-ice salt plume fluxes on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 56: ECG5D-SIV44
#     ECCO_L4_SEA_ICE_VELOCITY_05DEG_DAILY_V4R4
#     ECCO Sea-Ice Velocity - Daily Mean 0.5 Degree (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged sea-ice velocity interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 57: ECG5M-SIV44
#     ECCO_L4_SEA_ICE_VELOCITY_05DEG_MONTHLY_V4R4
#     ECCO Sea-Ice Velocity - Monthly Mean 0.5 Degree (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged sea-ice velocity interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 58: ECL5D-SIV44
#     ECCO_L4_SEA_ICE_VELOCITY_LLC0090GRID_DAILY_V4R4
#     ECCO Sea-Ice Velocity - Daily Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged sea-ice velocity on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 59: ECL5M-SIV44
#     ECCO_L4_SEA_ICE_VELOCITY_LLC0090GRID_MONTHLY_V4R4
#     ECCO Sea-Ice Velocity - Monthly Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged sea-ice velocity on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 60: ECL5S-SIV44
#     ECCO_L4_SEA_ICE_VELOCITY_LLC0090GRID_SNAPSHOT_V4R4
#     ECCO Sea-Ice Velocity - Snapshot llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides instantaneous sea-ice velocity on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 61: ECG5D-SSH44
#     ECCO_L4_SSH_05DEG_DAILY_V4R4
#     ECCO Sea Surface Height - Daily Mean 0.5 Degree (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged dynamic sea surface height interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 62: ECG5M-SSH44
#     ECCO_L4_SSH_05DEG_MONTHLY_V4R4
#     ECCO Sea Surface Height - Monthly Mean 0.5 Degree (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged dynamic sea surface height interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 63: ECL5D-SSH44
#     ECCO_L4_SSH_LLC0090GRID_DAILY_V4R4
#     ECCO Sea Surface Height - Daily Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged dynamic sea surface height and model sea level anomaly on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 64: ECL5M-SSH44
#     ECCO_L4_SSH_LLC0090GRID_MONTHLY_V4R4
#     ECCO Sea Surface Height - Monthly Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged dynamic sea surface height and model sea level anomaly on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 65: ECL5S-SSH44
#     ECCO_L4_SSH_LLC0090GRID_SNAPSHOT_V4R4
#     ECCO Sea Surface Height - Snapshot llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides instantaneous dynamic sea surface height and model sea level anomaly on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 66: ECG5D-STR44
#     ECCO_L4_STRESS_05DEG_DAILY_V4R4
#     ECCO Ocean and Sea-Ice Surface Stress - Daily Mean 0.5 Degree (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged ocean and sea-ice surface stress interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 67: ECG5M-STR44
#     ECCO_L4_STRESS_05DEG_MONTHLY_V4R4
#     ECCO Ocean and Sea-Ice Surface Stress - Monthly Mean 0.5 Degree (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged ocean and sea-ice surface stress interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 68: ECL5D-STR44
#     ECCO_L4_STRESS_LLC0090GRID_DAILY_V4R4
#     ECCO Ocean and Sea-Ice Surface Stress - Daily Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged ocean and sea-ice surface stress on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 69: ECL5M-STR44
#     ECCO_L4_STRESS_LLC0090GRID_MONTHLY_V4R4
#     ECCO Ocean and Sea-Ice Surface Stress - Monthly Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged ocean and sea-ice surface stress on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 70: ECG5D-OTS44
#     ECCO_L4_TEMP_SALINITY_05DEG_DAILY_V4R4
#     ECCO Ocean Temperature and Salinity - Daily Mean 0.5 Degree (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged ocean potential temperature and salinity interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 71: ECG5M-OTS44
#     ECCO_L4_TEMP_SALINITY_05DEG_MONTHLY_V4R4
#     ECCO Ocean Temperature and Salinity - Monthly Mean 0.5 Degree (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged ocean potential temperature and salinity interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 72: ECL5D-OTS44
#     ECCO_L4_TEMP_SALINITY_LLC0090GRID_DAILY_V4R4
#     ECCO Ocean Temperature and Salinity - Daily Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides daily-averaged ocean potential temperature and salinity on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 73: ECL5M-OTS44
#     ECCO_L4_TEMP_SALINITY_LLC0090GRID_MONTHLY_V4R4
#     ECCO Ocean Temperature and Salinity - Monthly Mean llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides monthly-averaged ocean potential temperature and salinity on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 74: ECL5S-OTS44
#     ECCO_L4_TEMP_SALINITY_LLC0090GRID_SNAPSHOT_V4R4
#     ECCO Ocean Temperature and Salinity - Snapshot llc90 Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides instantaneous ocean potential temperature and salinity on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 75: ECL5A-GRD44
#     ECCO_L4_GEOMETRY_LLC0090GRID_V4R4
#     ECCO Geometry Parameters for the Lat-Lon-Cap 90 (llc90) Native Model Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides geometric parameters for the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Parameters include areas and lengths of grid cell sides, horizontal and vertical coordinates of grid cell centers and corners, grid rotation angles, and global domain geometry including bathymetry and land/ocean masks.
#
#
# 76: ECG5A-GRD44
#     ECCO_L4_GEOMETRY_05DEG_V4R4
#     ECCO Geometry Parameters for the 0.5 degree Lat-Lon Model Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides geometric parameters for the regular 0.5-degree lat-lon grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Parameters include areas and lengths of grid cell sides, horizontal and vertical coordinates of grid cell centers and corners, and global domain geometry including bathymetry and land/ocean masks. Global domain geometry fields are approximate, having been interpolated from the ECCO lat-lon-cap 90 (llc90) native model grid. Note: exact budget closure calculations require ECCO fields and geometric parameters provided on the llc90 grid.
#
#
# 77: ECL5A-MIX44
#     ECCO_L4_OCEAN_3D_MIX_COEFFS_LLC0090GRID_V4R4
#     ECCO Ocean 3D Gent-Mcwilliams, Redi, and Background Vertical Diffusivity Coefficients for the Lat-Lon-Cap 90 (llc90) Native Model Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides 3D time-invariant coefficients for the Gent-McWilliams and Redi parameterizations and background vertical diffusivity on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.
#
#
# 78: ECG5A-MIX44
#     ECCO_L4_OCEAN_3D_MIX_COEFFS_05DEG_V4R4
#     ECCO Ocean 3D Gent-Mcwilliams, Redi, and Background Vertical Diffusivity Coefficients for the 0.5 degree Lat-Lon Model Grid (Version 4 Release 4)
# ---------------------------------------------------------------------------------------------------
# This dataset provides 3D time-invariant coefficients for the Gent-McWilliams and Redi parameterizations and background vertical diffusivity interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate.

# %%
ds_summary_fix
# Out:
# {'ECG5D-ATM44': {'title': 'ECCO Atmosphere Surface Temperature, Humidity, Wind, and Pressure - Daily Mean 0.5 Degree (Version 4 Release 4)',
#   'shortname': 'ECCO_L4_ATM_STATE_05DEG_DAILY_V4R4',
#   'summary_first_part': 'This dataset provides daily-averaged atmosphere surface temperature, humidity, wind, and pressure interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. ',
#   'summary': 'This dataset provides daily-averaged atmosphere surface temperature, humidity, wind, and pressure interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.',
#   'filename': 'ATM_SURFACE_TEMP_HUM_WIND_PRES_day_mean_1992-01-01_ECCO_V4r4_latlon_0p50deg.nc'},
#  'ECG5M-ATM44': {'title': 'ECCO Atmosphere Surface Temperature, Humidity, Wind, and Pressure - Monthly Mean 0.5 Degree (Version 4 Release 4)',
#   'shortname': 'ECCO_L4_ATM_STATE_05DEG_MONTHLY_V4R4',
#   'summary_first_part': 'This dataset provides monthly-averaged atmosphere surface temperature, humidity, wind, and pressure interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. ',
#   'summary': 'This dataset provides monthly-averaged atmosphere surface temperature, humidity, wind, and pressure interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.',
#   'filename': 'ATM_SURFACE_TEMP_HUM_WIND_PRES_mon_mean_1992-01_ECCO_V4r4_latlon_0p50deg.nc'},
#  'ECL5D-ATM44': {'title': 'ECCO Atmosphere Surface Temperature, Humidity, Wind, and Pressure - Daily Mean llc90 Grid (Version 4 Release 4)',
#   'shortname': 'ECCO_L4_ATM_STATE_LLC0090GRID_DAILY_V4R4',
#   'summary_first_part': 'This dataset provides daily-averaged atmosphere surface temperature, humidity, winds, and pressure on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. ',
#   'summary': 'This dataset provides daily-averaged atmosphere surface temperature, humidity, winds, and pressure on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.',
#   'filename': 'ATM_SURFACE_TEMP_HUM_WIND_PRES_day_mean_1992-01-01_ECCO_V4r4_native_llc0090.nc'},
#  'ECL5M-ATM44': {'title': 'ECCO Atmosphere Surface Temperature, Humidity, Wind, and Pressure - Monthly Mean llc90 Grid (Version 4 Release 4)',
#   'shortname': 'ECCO_L4_ATM_STATE_LLC0090GRID_MONTHLY_V4R4',
#   'summary_first_part': 'This dataset provides monthly-averaged atmosphere surface temperature, humidity, winds, and pressure on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. ',
#   'summary': 'This dataset provides monthly-averaged atmosphere surface temperature, humidity, winds, and pressure on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.',
#   'filename': 'ATM_SURFACE_TEMP_HUM_WIND_PRES_mon_mean_1992-01_ECCO_V4r4_native_llc0090.nc'},
#  'ECG5D-BOL44': {'title': 'ECCO Gent-McWilliams Ocean Bolus Velocity - Daily Mean 0.5 Degree (Version 4 Release 4)',
#   'shortname': 'ECCO_L4_BOLUS_05DEG_DAILY_V4R4',
#   'summary_first_part': 'This dataset provides daily-averaged Gent-McWilliams ocean bolus velocity interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. ',
#   'summary': 'This dataset provides daily-averaged Gent-McWilliams ocean bolus velocity interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.',
#   'filename': 'OCEAN_BOLUS_VELOCITY_day_mean_1992-01-01_ECCO_V4r4_latlon_0p50deg.nc'},
#  'ECG5M-BOL44': {'title': 'ECCO Gent-McWilliams Ocean Bolus Velocity - Monthly Mean 0.5 Degree (Version 4 Release 4)',
#   'shortname': 'ECCO_L4_BOLUS_05DEG_MONTHLY_V4R4',
#   'summary_first_part': 'This dataset provides monthly-averaged Gent-McWilliams ocean bolus velocity interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. ',
#   'summary': 'This dataset provides monthly-averaged Gent-McWilliams ocean bolus velocity interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.',
#   'filename': 'OCEAN_BOLUS_VELOCITY_mon_mean_1992-01_ECCO_V4r4_latlon_0p50deg.nc'},
#  'ECL5D-BOL44': {'title': 'ECCO Gent-McWilliams Ocean Bolus Velocity - Daily Mean llc90 Grid (Version 4 Release 4)',
#   'shortname': 'ECCO_L4_BOLUS_LLC0090GRID_DAILY_V4R4',
#   'summary_first_part': 'This dataset provides daily-averaged Gent-McWilliams ocean bolus velocity on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. ',
#   'summary': 'This dataset provides daily-averaged Gent-McWilliams ocean bolus velocity on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.',
#   'filename': 'OCEAN_BOLUS_VELOCITY_day_mean_1992-01-01_ECCO_V4r4_native_llc0090.nc'},
#  'ECL5M-BOL44': {'title': 'ECCO Gent-McWilliams Ocean Bolus Velocity - Monthly Mean llc90 Grid (Version 4 Release 4)',
#   'shortname': 'ECCO_L4_BOLUS_LLC0090GRID_MONTHLY_V4R4',
#   'summary_first_part': 'This dataset provides monthly-averaged Gent-McWilliams bolus ocean velocity on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. ',
#   'summary': 'This dataset provides monthly-averaged Gent-McWilliams bolus ocean velocity on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.',
#   'filename': 'OCEAN_BOLUS_VELOCITY_mon_mean_1992-01_ECCO_V4r4_native_llc0090.nc'},
#  'ECG5D-ODE44': {'title': 'ECCO Ocean Density, Stratification, and Hydrostatic Pressure - Daily Mean 0.5 Degree (Version 4 Release 4)',
#   'shortname': 'ECCO_L4_DENS_STRAT_PRESS_05DEG_DAILY_V4R4',
#   'summary_first_part': 'This dataset provides daily-averaged ocean density, stratification, and hydrostatic pressure interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. ',
#   'summary': 'This dataset provides daily-averaged ocean density, stratification, and hydrostatic pressure interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.',
#   'filename': 'OCEAN_DENS_STRAT_PRESS_day_mean_1992-01-01_ECCO_V4r4_latlon_0p50deg.nc'},
#  'ECG5M-ODE44': {'title': 'ECCO Ocean Density, Stratification, and Hydrostatic Pressure - Monthly Mean 0.5 Degree (Version 4 Release 4)',
#   'shortname': 'ECCO_L4_DENS_STRAT_PRESS_05DEG_MONTHLY_V4R4',
#   'summary_first_part': 'This dataset provides monthly-averaged ocean density, stratification, and hydrostatic pressure interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. ',
#   'summary': 'This dataset provides monthly-averaged ocean density, stratification, and hydrostatic pressure interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.',
#   'filename': 'OCEAN_DENS_STRAT_PRESS_mon_mean_1992-01_ECCO_V4r4_latlon_0p50deg.nc'},
#  'ECL5D-ODE44': {'title': 'ECCO Ocean Density, Stratification, and Hydrostatic Pressure - Daily Mean llc90 Grid (Version 4 Release 4)',
#   'shortname': 'ECCO_L4_DENS_STRAT_PRESS_LLC0090GRID_DAILY_V4R4',
#   'summary_first_part': 'This dataset provides daily-averaged ocean density, stratification, and hydrostatic pressure on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. ',
#   'summary': 'This dataset provides daily-averaged ocean density, stratification, and hydrostatic pressure on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.',
#   'filename': 'OCEAN_DENS_STRAT_PRESS_day_mean_1992-01-01_ECCO_V4r4_native_llc0090.nc'},
#  'ECL5M-ODE44': {'title': 'ECCO Ocean Density, Stratification, and Hydrostatic Pressure - Monthly Mean llc90 Grid (Version 4 Release 4)',
#   'shortname': 'ECCO_L4_DENS_STRAT_PRESS_LLC0090GRID_MONTHLY_V4R4',
#   'summary_first_part': 'This dataset provides monthly-averaged ocean density, stratification, and hydrostatic pressure on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. ',
#   'summary': 'This dataset provides monthly-averaged ocean density, stratification, and hydrostatic pressure on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.',
#   'filename': 'OCEAN_DENS_STRAT_PRESS_mon_mean_1992-01_ECCO_V4r4_native_llc0090.nc'},
#  'ECG5D-FRE44': {'title': 'ECCO Ocean and Sea-Ice Surface Freshwater Fluxes - Daily Mean 0.5 Degree (Version 4 Release 4)',
#   'shortname': 'ECCO_L4_FRESH_FLUX_05DEG_DAILY_V4R4',
#   'summary_first_part': 'This dataset provides daily-averaged ocean and sea-ice surface freshwater fluxes interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. ',
#   'summary': 'This dataset provides daily-averaged ocean and sea-ice surface freshwater fluxes interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.',
#   'filename': 'OCEAN_AND_ICE_SURFACE_FW_FLUX_day_mean_1992-01-01_ECCO_V4r4_latlon_0p50deg.nc'},
#  'ECG5M-FRE44': {'title': 'ECCO Ocean and Sea-Ice Surface Freshwater Fluxes - Monthly Mean 0.5 Degree (Version 4 Release 4)',
#   'shortname': 'ECCO_L4_FRESH_FLUX_05DEG_MONTHLY_V4R4',
#   'summary_first_part': 'This dataset provides monthly-averaged ocean and sea-ice surface freshwater fluxes interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. ',
#   'summary': 'This dataset provides monthly-averaged ocean and sea-ice surface freshwater fluxes interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.',
#   'filename': 'OCEAN_AND_ICE_SURFACE_FW_FLUX_mon_mean_1992-01_ECCO_V4r4_latlon_0p50deg.nc'},
#  'ECL5D-FRE44': {'title': 'ECCO Ocean and Sea-Ice Surface Freshwater Fluxes - Daily Mean llc90 Grid (Version 4 Release 4)',
#   'shortname': 'ECCO_L4_FRESH_FLUX_LLC0090GRID_DAILY_V4R4',
#   'summary_first_part': 'This dataset provides daily-averaged ocean and sea-ice surface freshwater fluxes on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. ',
#   'summary': 'This dataset provides daily-averaged ocean and sea-ice surface freshwater fluxes on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.',
#   'filename': 'OCEAN_AND_ICE_SURFACE_FW_FLUX_day_mean_1992-01-01_ECCO_V4r4_native_llc0090.nc'},
#  'ECL5M-FRE44': {'title': 'ECCO Ocean and Sea-Ice Surface Freshwater Fluxes - Monthly Mean llc90 Grid (Version 4 Release 4)',
#   'shortname': 'ECCO_L4_FRESH_FLUX_LLC0090GRID_MONTHLY_V4R4',
#   'summary_first_part': 'This dataset provides monthly-averaged ocean and sea-ice surface freshwater fluxes on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. ',
#   'summary': 'This dataset provides monthly-averaged ocean and sea-ice surface freshwater fluxes on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.',
#   'filename': 'OCEAN_AND_ICE_SURFACE_FW_FLUX_mon_mean_1992-01_ECCO_V4r4_native_llc0090.nc'},
#  'ECTSS-MAP44': {'title': 'ECCO Global Mean Atmospheric Pressure - Snapshot (Version 4 Release 4)',
#   'shortname': 'ECCO_L4_GMAP_TIME_SERIES_SNAPSHOT_V4R4',
#   'summary_first_part': 'This dataset provides instantaneous hourly global mean atmospheric surface pressure over the ocean and sea-ice from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. ',
#   'summary': 'This dataset provides instantaneous hourly global mean atmospheric surface pressure over the ocean and sea-ice from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.',
#   'filename': 'GLOBAL_MEAN_ATM_SURFACE_PRES_snap_ECCO_V4r4_1D.nc'},
#  'ECTSD-MSL44': {'title': 'ECCO Global Mean Sea Level - Daily Mean (Version 4 Release 4)',
#   'shortname': 'ECCO_L4_GMSL_TIME_SERIES_DAILY_V4R4',
#   'summary_first_part': 'This dataset provides daily-averaged global mean sea level anomalies including barystatic and sterodynamic terms from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. ',
#   'summary': 'This dataset provides daily-averaged global mean sea level anomalies including barystatic and sterodynamic terms from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.',
#   'filename': 'GLOBAL_MEAN_SEA_LEVEL_day_mean_ECCO_V4r4_1D.nc'},
#  'ECTSM-MSL44': {'title': 'ECCO Global Mean Sea Level - Monthly Mean (Version 4 Release 4)',
#   'shortname': 'ECCO_L4_GMSL_TIME_SERIES_MONTHLY_V4R4',
#   'summary_first_part': 'This dataset provides monthly-averaged global mean sea level anomalies including barystatic and sterodynamic terms from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. ',
#   'summary': 'This dataset provides monthly-averaged global mean sea level anomalies including barystatic and sterodynamic terms from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.',
#   'filename': 'GLOBAL_MEAN_SEA_LEVEL_mon_mean_ECCO_V4r4_1D.nc'},
#  'ECG5D-HEA44': {'title': 'ECCO Ocean and Sea-Ice Surface Heat Fluxes - Daily Mean 0.5 Degree (Version 4 Release 4)',
#   'shortname': 'ECCO_L4_HEAT_FLUX_05DEG_DAILY_V4R4',
#   'summary_first_part': 'This dataset provides daily-averaged ocean and sea-ice surface heat fluxes interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. ',
#   'summary': 'This dataset provides daily-averaged ocean and sea-ice surface heat fluxes interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.',
#   'filename': 'OCEAN_AND_ICE_SURFACE_HEAT_FLUX_day_mean_1992-01-01_ECCO_V4r4_latlon_0p50deg.nc'},
#  'ECG5M-HEA44': {'title': 'ECCO Ocean and Sea-Ice Surface Heat Fluxes - Monthly Mean 0.5 Degree (Version 4 Release 4)',
#   'shortname': 'ECCO_L4_HEAT_FLUX_05DEG_MONTHLY_V4R4',
#   'summary_first_part': 'This dataset provides monthly-averaged ocean and sea-ice surface heat fluxes interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. ',
#   'summary': 'This dataset provides monthly-averaged ocean and sea-ice surface heat fluxes interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.',
#   'filename': 'OCEAN_AND_ICE_SURFACE_HEAT_FLUX_mon_mean_1992-01_ECCO_V4r4_latlon_0p50deg.nc'},
#  'ECL5D-HEA44': {'title': 'ECCO Ocean and Sea-Ice Surface Heat Fluxes - Daily Mean llc90 Grid (Version 4 Release 4)',
#   'shortname': 'ECCO_L4_HEAT_FLUX_LLC0090GRID_DAILY_V4R4',
#   'summary_first_part': 'This dataset provides daily-averaged ocean and sea-ice surface heat fluxes on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. ',
#   'summary': 'This dataset provides daily-averaged ocean and sea-ice surface heat fluxes on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.',
#   'filename': 'OCEAN_AND_ICE_SURFACE_HEAT_FLUX_day_mean_1992-01-01_ECCO_V4r4_native_llc0090.nc'},
#  'ECL5M-HEA44': {'title': 'ECCO Ocean and Sea-Ice Surface Heat Fluxes - Monthly Mean llc90 Grid (Version 4 Release 4)',
#   'shortname': 'ECCO_L4_HEAT_FLUX_LLC0090GRID_MONTHLY_V4R4',
#   'summary_first_part': 'This dataset provides monthly-averaged ocean and sea-ice surface heat fluxes on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. ',
#   'summary': 'This dataset provides monthly-averaged ocean and sea-ice surface heat fluxes on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.',
#   'filename': 'OCEAN_AND_ICE_SURFACE_HEAT_FLUX_mon_mean_1992-01_ECCO_V4r4_native_llc0090.nc'},
#  'ECG5D-OML44': {'title': 'ECCO Ocean Mixed Layer Depth - Daily Mean 0.5 Degree (Version 4 Release 4)',
#   'shortname': 'ECCO_L4_MIXED_LAYER_DEPTH_05DEG_DAILY_V4R4',
#   'summary_first_part': 'This dataset provides daily-averaged ocean mixed layer depth interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. ',
#   'summary': 'This dataset provides daily-averaged ocean mixed layer depth interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.',
#   'filename': 'OCEAN_MIXED_LAYER_DEPTH_day_mean_1992-01-01_ECCO_V4r4_latlon_0p50deg.nc'},
#  'ECG5M-OML44': {'title': 'ECCO Ocean Mixed Layer Depth - Monthly Mean 0.5 Degree (Version 4 Release 4)',
#   'shortname': 'ECCO_L4_MIXED_LAYER_DEPTH_05DEG_MONTHLY_V4R4',
#   'summary_first_part': 'This dataset provides monthly-averaged ocean mixed layer depth interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. ',
# ...
#   'filename': 'OCEAN_TEMPERATURE_SALINITY_mon_mean_1992-01_ECCO_V4r4_latlon_0p50deg.nc'},
#  'ECL5D-OTS44': {'title': 'ECCO Ocean Temperature and Salinity - Daily Mean llc90 Grid (Version 4 Release 4)',
#   'shortname': 'ECCO_L4_TEMP_SALINITY_LLC0090GRID_DAILY_V4R4',
#   'summary_first_part': 'This dataset provides daily-averaged ocean potential temperature and salinity on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. ',
#   'summary': 'This dataset provides daily-averaged ocean potential temperature and salinity on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.',
#   'filename': 'OCEAN_TEMPERATURE_SALINITY_day_mean_1992-01-01_ECCO_V4r4_native_llc0090.nc'},
#  'ECL5M-OTS44': {'title': 'ECCO Ocean Temperature and Salinity - Monthly Mean llc90 Grid (Version 4 Release 4)',
#   'shortname': 'ECCO_L4_TEMP_SALINITY_LLC0090GRID_MONTHLY_V4R4',
#   'summary_first_part': 'This dataset provides monthly-averaged ocean potential temperature and salinity on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. ',
#   'summary': 'This dataset provides monthly-averaged ocean potential temperature and salinity on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.',
#   'filename': 'OCEAN_TEMPERATURE_SALINITY_mon_mean_1992-01_ECCO_V4r4_native_llc0090.nc'},
#  'ECL5S-OTS44': {'title': 'ECCO Ocean Temperature and Salinity - Snapshot llc90 Grid (Version 4 Release 4)',
#   'shortname': 'ECCO_L4_TEMP_SALINITY_LLC0090GRID_SNAPSHOT_V4R4',
#   'summary_first_part': 'This dataset provides instantaneous ocean potential temperature and salinity on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. ',
#   'summary': 'This dataset provides instantaneous ocean potential temperature and salinity on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.',
#   'filename': 'OCEAN_TEMPERATURE_SALINITY_snap_1992-01-01T000000_ECCO_V4r4_native_llc0090.nc'},
#  'ECL5A-GRD44': {'title': 'ECCO Geometry Parameters for the Lat-Lon-Cap 90 (llc90) Native Model Grid (Version 4 Release 4)',
#   'shortname': 'ECCO_L4_GEOMETRY_LLC0090GRID_V4R4',
#   'summary_first_part': 'This dataset provides geometric parameters for the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Parameters include areas and lengths of grid cell sides, horizontal and vertical coordinates of grid cell centers and corners, grid rotation angles, and global domain geometry including bathymetry and land/ocean masks. ',
#   'summary': 'This dataset provides geometric parameters for the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Parameters include areas and lengths of grid cell sides, horizontal and vertical coordinates of grid cell centers and corners, grid rotation angles, and global domain geometry including bathymetry and land/ocean masks. Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.',
#   'filename': 'GRID_GEOMETRY_ECCO_v4r4_native_llc0090.nc'},
#  'ECG5A-GRD44': {'title': 'ECCO Geometry Parameters for the 0.5 degree Lat-Lon Model Grid (Version 4 Release 4)',
#   'shortname': 'ECCO_L4_GEOMETRY_05DEG_V4R4',
#   'summary_first_part': 'This dataset provides geometric parameters for the regular 0.5-degree lat-lon grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Parameters include areas and lengths of grid cell sides, horizontal and vertical coordinates of grid cell centers and corners, and global domain geometry including bathymetry and land/ocean masks. Global domain geometry fields are approximate, having been interpolated from the ECCO lat-lon-cap 90 (llc90) native model grid. Note: exact budget closure calculations require ECCO fields and geometric parameters provided on the llc90 grid. ',
#   'summary': 'This dataset provides geometric parameters for the regular 0.5-degree lat-lon grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Parameters include areas and lengths of grid cell sides, horizontal and vertical coordinates of grid cell centers and corners, and global domain geometry including bathymetry and land/ocean masks. Global domain geometry fields are approximate, having been interpolated from the ECCO lat-lon-cap 90 (llc90) native model grid. Note: exact budget closure calculations require ECCO fields and geometric parameters provided on the llc90 grid. Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.',
#   'filename': 'GRID_GEOMETRY_ECCO_v4r4_latlon_0p50deg.nc'},
#  'ECL5A-MIX44': {'title': 'ECCO Ocean 3D Gent-Mcwilliams, Redi, and Background Vertical Diffusivity Coefficients for the Lat-Lon-Cap 90 (llc90) Native Model Grid (Version 4 Release 4)',
#   'shortname': 'ECCO_L4_OCEAN_3D_MIX_COEFFS_LLC0090GRID_V4R4',
#   'summary_first_part': 'This dataset provides 3D time-invariant coefficients for the Gent-McWilliams and Redi parameterizations and background vertical diffusivity on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. ',
#   'summary': 'This dataset provides 3D time-invariant coefficients for the Gent-McWilliams and Redi parameterizations and background vertical diffusivity on the lat-lon-cap 90 (llc90) native model grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.',
#   'filename': 'OCEAN_3D_MIXING_COEFFS_ECCO_V4r4_native_llc0090.nc'},
#  'ECG5A-MIX44': {'title': 'ECCO Ocean 3D Gent-Mcwilliams, Redi, and Background Vertical Diffusivity Coefficients for the 0.5 degree Lat-Lon Model Grid (Version 4 Release 4)',
#   'shortname': 'ECCO_L4_OCEAN_3D_MIX_COEFFS_05DEG_V4R4',
#   'summary_first_part': 'This dataset provides 3D time-invariant coefficients for the Gent-McWilliams and Redi parameterizations and background vertical diffusivity interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. ',
#   'summary': 'This dataset provides 3D time-invariant coefficients for the Gent-McWilliams and Redi parameterizations and background vertical diffusivity interpolated to a regular 0.5-degree grid from the ECCO Version 4 Release 4 (V4r4) ocean and sea-ice state estimate. Estimating the Circulation and Climate of the Ocean (ECCO) state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of a global, nominally 1-degree configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea-ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.',
#   'filename': 'OCEAN_3D_MIXING_COEFFS_ECCO_V4r4_latlon_0p50deg.nc'}}

# %%
output_dir = Path('/home/ifenty/git_repos_others/ECCO-GROUP/ECCO-ACCESS/metadata/ECCOv4r4_metadata_json')

# %%
with open(output_dir / 'ECCOv4r4_dataset_summary.json', 'w') as outfile:
    outfile.write(json.dumps(ds_summary_fix, indent=4))

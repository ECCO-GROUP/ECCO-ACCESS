# %%
import argparse
import dask
import json
import netCDF4 as nc4
import numpy as np
import pandas as pd
from pathlib import Path
from pprint import pprint
import time
import warnings
import xarray as xr
from dask import delayed
warnings.filterwarnings('ignore')

# %%
import warnings
warnings.filterwarnings('ignore')
import dask
dask.config.set({'temporary_directory': '/mnt/intraid/ian1/ifenty/dask_tmp'})

# Works on Ian's Machine, but not necessary
from dask.distributed import Client, progress
#client = Client(processes=False, threads_per_worker=48)
client = Client(processes=False, n_workers=1, threads_per_worker=8,memory_limit='128GB')
client
# Out:
# <Client: 'inproc://137.78.251.47/171569/1' processes=1 threads=8, memory=128.00 GB>

# %%
def get_groupings(base_dir, grid_type, time_type):
    groupings = dict()
    tmp = Path(f'{base_dir}/{grid_type}/{time_type}')
    print(tmp)
    if tmp.exists():
        for pi, p in enumerate(tmp.iterdir()):
            grouping = str(p).split('/')[-1]
            groupings[pi] = dict()
            groupings[pi]['name'] = grouping
            groupings[pi]['grid'] = grid_type
            groupings[pi]['time_type'] = time_type
            groupings[pi]['directory'] = p
            
    return groupings

# %%
@delayed
def load_ecco_file(filename):
    time_start=time.time()
    print(filename.name)
    ecco_field = xr.open_dataset(filename).load()
    return ecco_field

# %%
@delayed
def get_minmax(ecco_field):
    results_da = dict()
    for dv in ecco_field.data_vars:
        results_da[dv] = dict()
        tmp_min = ecco_field[dv].min()
        tmp_max = ecco_field[dv].max()
        
        results_da[dv]['valid_min'] = tmp_min.values
        results_da[dv]['valid_max'] = tmp_max.values
    
    return results_da

# %%
def construct_DS(results, grouping_info, ds_title, ds_id, delta_time):
    dvs = list(results_da_compute[0].keys())

    X = dict()
    DAs = []

    # loop through all data varaibles
    for dv in dvs:
        print(dv)
        X[dv] = dict()
        X[dv]['valid_max'] = []
        X[dv]['valid_min'] = []

        # loop through all records
        for r in results:
            X[dv]['valid_min'].append(r[dv]['valid_min'])
            X[dv]['valid_max'].append(r[dv]['valid_max'])

        # final min max for all records
        valid_min = np.array(X[dv]['valid_min']).min() 
        valid_max = np.array(X[dv]['valid_max']).max() 
           
        # construct data array with valid min and max
        tmp = xr.DataArray([valid_min, valid_max], dims=['valid_min_max'])
        tmp.name = dv
        DAs.append(tmp)

        
    DS = xr.merge(DAs)
    DS.attrs['title']     = ds_title
    DS.attrs['name']      = grouping_info['name']
    DS.attrs['grid']      = grouping_info['grid']
    DS.attrs['time_type'] = grouping_info['time_type']
    DS.attrs['id']        = ds_id
    DS.attrs['shortname'] = ds_id.split('/')[1]
    DS.attrs['directory'] = str(grouping_info['directory'])
    DS.attrs['calc_time_seconds'] = delta_time

    return DS

# %% [markdown]
# ## Inputs

# %%
dataset_base_dir = Path('/home/ifenty/ian1/ifenty/ECCOv4/Version4/Release4/podaac/')

# %%
grids = ['native','latlon']
time_avgs = ['day_inst', 'day_mean','mon_mean']

# %%
def f(ecco_files):
    results = []
    
    for file in ecco_files:
        ecco_field = load_ecco_file(file)
        result = get_minmax(ecco_field)
        results.append(result)
        
    return results

# %% [markdown]
# ## Calc

# %%
time_type = time_avgs[2]
grid_type = grids[0]

groupings = get_groupings(dataset_base_dir, grid_type, time_type)
# Out:
# /home/ifenty/ian1/ifenty/ECCOv4/Version4/Release4/podaac/native/mon_mean

# %%
for gi in groupings:
    print(gi, groupings[gi]['name'])
# Out:
# 0 ATM_SURFACE_TEMP_HUM_WIND_PRES
# 1 OCEAN_3D_MOMENTUM_TEND
# 2 OCEAN_3D_SALINITY_FLUX
# 3 OCEAN_3D_TEMPERATURE_FLUX
# 4 OCEAN_3D_VOLUME_FLUX
# 5 OCEAN_AND_ICE_SURFACE_FW_FLUX
# 6 OCEAN_AND_ICE_SURFACE_HEAT_FLUX
# 7 OCEAN_AND_ICE_SURFACE_STRESS
# 8 OCEAN_BOLUS_STREAMFUNCTION
# 9 OCEAN_BOLUS_VELOCITY
# 10 OCEAN_BOTTOM_PRESSURE
# 11 OCEAN_DENS_STRAT_PRESS
# 12 OCEAN_MIXED_LAYER_DEPTH
# 13 OCEAN_TEMPERATURE_SALINITY
# 14 OCEAN_VELOCITY
# 15 SEA_ICE_CONC_THICKNESS
# 16 SEA_ICE_HORIZ_VOLUME_FLUX
# 17 SEA_ICE_SALT_PLUME_FLUX
# 18 SEA_ICE_VELOCITY
# 19 SEA_SURFACE_HEIGHT

# %%
gi = 3
print(groupings[gi])
# Out:
# {'name': 'OCEAN_3D_TEMPERATURE_FLUX', 'grid': 'native', 'time_type': 'mon_mean', 'directory': PosixPath('/home/ifenty/ian1/ifenty/ECCOv4/Version4/Release4/podaac/native/mon_mean/OCEAN_3D_TEMPERATURE_FLUX')}

# %%
data_dir = groupings[gi]['directory']
glob_name = '*ECCO*nc'
ecco_files = np.sort(list(data_dir.glob(glob_name)))

# %%
start_time = time.time()
results_da_compute = dask.compute(f(ecco_files))[0]
delta_time = time.time() - start_time
# Out:
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1993-05_ECCO_V4r4_native_llc0090.ncOCEAN_3D_TEMPERATURE_FLUX_mon_mean_2008-02_ECCO_V4r4_native_llc0090.ncOCEAN_3D_TEMPERATURE_FLUX_mon_mean_2005-09_ECCO_V4r4_native_llc0090.ncOCEAN_3D_TEMPERATURE_FLUX_mon_mean_2011-10_ECCO_V4r4_native_llc0090.nc
#
#
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2007-11_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2013-05_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2012-03_ECCO_V4r4_native_llc0090.ncOCEAN_3D_TEMPERATURE_FLUX_mon_mean_1992-01_ECCO_V4r4_native_llc0090.nc
#
#
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2001-09_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2011-09_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2010-07_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2010-09_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2008-09_ECCO_V4r4_native_llc0090.ncOCEAN_3D_TEMPERATURE_FLUX_mon_mean_2004-03_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2006-09_ECCO_V4r4_native_llc0090.nc
#
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2016-03_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1995-01_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2006-12_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2000-07_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1996-08_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2009-05_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2016-07_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1992-02_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2006-05_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1995-02_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2010-02_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2008-12_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2000-09_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2011-03_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1992-04_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1999-06_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2017-10_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1994-02_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1996-02_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2014-02_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2001-11_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1997-09_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1995-11_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2010-11_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2003-09_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1997-04_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2003-02_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2017-11_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1999-12_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2003-04_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1999-10_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2004-10_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2006-07_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2001-01_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2008-08_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2010-10_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2000-04_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2005-07_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1995-06_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1993-08_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2003-03_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2007-12_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1997-08_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1993-11_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1996-01_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1996-03_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1997-11_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2015-06_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1996-04_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2014-03_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2001-12_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1994-01_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2013-06_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2004-05_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1997-03_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2014-07_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2013-07_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2014-04_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1996-06_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2006-04_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1993-03_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1998-04_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2008-07_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2016-11_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2006-02_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1997-02_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2002-04_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1996-05_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2016-10_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2013-01_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2015-03_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2012-02_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2003-08_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2007-06_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2009-08_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1993-12_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2007-05_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1998-01_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2017-08_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2004-01_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2007-03_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2000-02_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1992-09_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2011-12_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2012-11_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2010-03_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2009-01_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2003-05_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2011-08_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2010-08_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2000-01_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2017-12_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2017-09_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1992-12_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2006-10_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2016-09_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1997-05_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2015-01_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2003-12_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2017-04_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1995-03_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2015-12_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1995-12_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1994-09_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1994-10_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1992-11_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2007-04_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2011-02_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2013-02_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2017-05_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2002-06_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2006-06_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2004-06_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1999-04_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2007-09_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2016-06_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2013-04_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2010-04_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2014-10_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2001-02_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2002-12_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2007-07_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2004-07_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1993-06_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1999-09_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1992-10_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2014-08_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1995-07_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1992-06_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2013-08_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2015-10_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2005-02_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2000-10_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2006-03_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2001-06_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2010-06_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2008-11_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2005-03_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2012-01_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1995-05_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2001-08_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1992-03_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1994-07_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2013-11_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1994-04_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2013-03_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2005-08_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2005-11_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1995-10_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2016-08_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2001-07_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2002-10_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2016-12_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2012-08_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1998-07_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2005-01_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2015-08_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2000-11_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1995-09_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2008-06_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2004-04_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2013-12_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2004-02_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1996-07_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1994-11_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1998-09_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2003-11_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1998-05_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2002-09_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1993-10_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2009-07_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2012-07_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2009-06_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2011-05_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2012-09_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1993-07_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2002-03_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2013-10_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2016-02_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2007-02_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2011-01_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2015-09_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1998-02_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2007-01_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2005-04_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2017-02_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2011-11_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2000-12_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1999-07_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1998-08_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2005-05_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2014-09_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2007-10_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2002-11_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2006-11_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2012-12_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2001-03_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1999-05_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2013-09_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2012-06_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2014-06_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2002-07_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2009-10_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2015-04_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2015-11_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2006-08_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2008-04_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2004-11_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2002-01_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2003-01_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2010-12_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2012-10_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1992-08_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1998-12_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2017-03_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2008-03_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1994-08_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1993-04_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2003-06_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1996-11_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1999-08_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1999-11_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2008-10_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1995-04_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2017-01_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2017-06_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2014-12_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1998-11_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2015-02_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2011-04_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1998-10_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2009-11_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1998-03_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1999-02_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2012-04_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2008-01_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2005-10_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2014-11_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1995-08_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2001-04_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1992-07_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2001-10_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2009-02_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1999-03_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2015-05_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2009-09_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2000-05_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1994-05_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1996-10_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1997-10_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2003-07_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2003-10_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1996-09_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2016-04_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2005-12_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2009-12_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2010-05_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2007-08_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1993-02_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2006-01_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2004-12_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2012-05_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2002-05_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2002-02_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2010-01_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1998-06_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2014-05_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2015-07_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2004-09_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2004-08_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2016-05_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2017-07_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2014-01_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2005-06_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1993-09_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2011-07_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1993-01_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1997-06_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2009-03_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2000-08_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2009-04_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1997-07_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1997-01_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1994-12_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1999-01_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2008-05_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2011-06_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1994-03_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2002-08_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2000-03_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2016-01_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1996-12_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1997-12_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1992-05_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2001-05_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_1994-06_ECCO_V4r4_native_llc0090.nc
# OCEAN_3D_TEMPERATURE_FLUX_mon_mean_2000-06_ECCO_V4r4_native_llc0090.nc

# %%
tmp_file = xr.open_dataset(ecco_files[0])
ds_title = tmp_file.attrs['title']
ds_id = tmp_file.attrs['id']

# %%
print(delta_time)
# Out:
# 240.51060318946838

# %%
DS = construct_DS(results_da_compute, groupings[gi], ds_title, ds_id, delta_time)
DS
# Out:
# ADVx_TH
# DFxE_TH
# ADVy_TH
# DFyE_TH
# ADVr_TH
# DFrE_TH
# DFrI_TH
# <xarray.Dataset>
# Dimensions:  (valid_min_max: 2)
# Dimensions without coordinates: valid_min_max
# Data variables:
#     ADVx_TH  (valid_min_max) float32 -28231902.0 36523468.0
#     DFxE_TH  (valid_min_max) float32 -348717.34 574455.7
#     ADVy_TH  (valid_min_max) float32 -31236064.0 43466144.0
#     DFyE_TH  (valid_min_max) float32 -414038.94 921333.6
#     ADVr_TH  (valid_min_max) float32 -106447560.0 60402470.0
#     DFrE_TH  (valid_min_max) float32 -2370699.5 2275023.8
#     DFrI_TH  (valid_min_max) float32 -2385608.8 3000093.5
# Attributes:
#     title:              ECCO Ocean Three-Dimensional Potential Temperature Fl...
#     name:               OCEAN_3D_TEMPERATURE_FLUX
#     grid:               native
#     time_type:          mon_mean
#     id:                 10.5067/ECL5M-3TF44
#     shortname:          ECL5M-3TF44
#     directory:          /home/ifenty/ian1/ifenty/ECCOv4/Version4/Release4/pod...
#     calc_time_seconds:  240.51060318946838

# %%
filename = f"valid_minmax_{DS.attrs['name']}_{DS.attrs['grid']}_{DS.attrs['time_type']}_{DS.attrs['shortname']}.nc"
filename
# Out:
# 'valid_minmax_SEA_ICE_VELOCITY_native_mon_mean_ECL5M-SIV44.nc'

# %%
output_dir = Path('/home/ifenty/ian1/ifenty/ECCOv4/Version4/Release4/podaac/valid_minmax_20210311c')
if not output_dir.exists():
    output_dir.mkdir()

# %%
DS.to_netcdf(output_dir / filename)

# %%
import argparse
import dask
import json
import netCDF4 as nc4
import numpy as np
import pandas as pd
from pathlib import Path
from pprint import pprint
import time
import warnings
import xarray as xr
from dask import delayed
import datetime
import random
warnings.filterwarnings('ignore')

# %%
def load_valid_minmax(valid_minmax_dir):
    valid_minmax_files = list(valid_minmax_dir.glob('**/valid_minmax*.nc'))

    minmax = dict()
    for mmf in valid_minmax_files:
        tmp = xr.open_dataset(mmf)
        shortname = tmp.attrs['shortname']
        id = tmp.attrs['id']

        minmax[shortname] = dict()
        for dv in tmp.data_vars:
            minmax[shortname][dv] = dict()
            minmax[shortname][dv]['valid_min'] = tmp[dv].values[0]
            minmax[shortname][dv]['valid_max'] = tmp[dv].values[1]
                    
    return minmax

# %%
comment_fix = dict()

comment_fix["oceSPDep"] = dict()
comment_fix["oceSPDep"]['filename'] = "SEA_ICE_SALT_PLUME_FLUX"
comment_fix["oceSPDep"]['comments'] = "Depth of parameterized salt plumes formed due to brine rejection during sea-ice formation."

comment_fix["RHOAnoma"] = dict()
comment_fix["RHOAnoma"]['filename'] = "OCEAN_DENS_STRAT_PRESS"
comment_fix["RHOAnoma"]['comments'] = "In-situ seawater density anomaly relative to the reference density, rhoConst. rhoConst = 1029 kg m-3"

comment_fix["SALT"] = dict()
comment_fix["SALT"]['filename'] = "OCEAN_TEMPERATURE_SALINITY"
comment_fix["SALT"]['comments'] = "Defined using CF convention 'Sea water salinity is the salt content of sea water, often on the Practical Salinity Scale of 1978. However, the unqualified term 'salinity' is generic and does not necessarily imply any particular method of calculation. The units of salinity are dimensionless and the units attribute should normally be given as 1e-3 or 0.001 i.e. parts per thousand.' see https://cfconventions.org/Data/cf-standard-names/73/build/cf-standard-name-table.html"

comment_fix["SIsnPrcp"] = dict()
comment_fix["SIsnPrcp"]['filename'] = "OCEAN_AND_ICE_SURFACE_FW_FLUX"
comment_fix["SIsnPrcp"]['comments'] = "Snow precipitation rate over sea-ice, averaged over the entire model grid cell."

# %%
def apply_fixes(ecco_filename, minmax, comment_fix, qc_prob):

    comment_keys = list(comment_fix.keys())
    
    try:
        with nc4.Dataset(ecco_filename, mode='r+') as tmp_ds:
            shortname = tmp_ds.id.split('/')[1]

            print(shortname)
            if shortname in minmax.keys():
                
                nc_dvs = list(tmp_ds.variables)
                minmax_dvs = list(minmax[shortname].keys())
                
                for minmax_dv in minmax_dvs:
                    if minmax_dv in nc_dvs:
                        new_valid_min = minmax[shortname][minmax_dv]['valid_min']
                        new_valid_max = minmax[shortname][minmax_dv]['valid_max']

                        qc_rand = random.random()
                            
                        v = tmp_ds.variables[minmax_dv]
                        
                        if qc_rand < qc_prob:
                            # load actual vmin vmax here
                            v_min = np.nanmin(v[:])#.values)
                            v_max = np.nanmax(v[:])#tmp_ds_xr_v.values)
                                                        
                            # pull old valid min max attributes
                            old_valid_min = v.valid_min
                            old_valid_max = v.valid_max

                            print(f'   QC {minmax_dv}')
                            print(f'   QC current dv actual vmin/vmax : {v_min:.12} {v_max:.12}')
                            print(f'   QC old valid_min/max           : {old_valid_min:.12} {old_valid_max:.12}')
                            print(f'   QC new valid_min/max           : {new_valid_min:.12} {new_valid_max:.12}')

                            if old_valid_min > v_min or old_valid_max < v_max:
                                print('   ...old valid min/max was wrong')
                                print('   1. old valid min >= vmin', old_valid_min, v_min, old_valid_min >= v_min)
                                print('   2. old valid max <= vmax', old_valid_max, v_max, old_valid_max <= v_max)
                            else:
                                print('   ...old valid min/max was ok')
       
                            if new_valid_min > v_min or new_valid_max < v_max:
                                print('   ...new valid min/max is wrong')
                                print('   1. new valid min >= vmin', new_valid_min, v_min, new_valid_min >= v_min)
                                print('   2. new valid max <= vmax', new_valid_max, v_max, new_valid_max <= v_max)
                                return 0

                            else:
                                print('   ...new valid min/max is ok')
                                
                                      
                        v.setncattr("valid_min", new_valid_min)
                        v.setncattr("valid_max", new_valid_max)

                        # fix units on EXFatemp
                        if minmax_dv == 'EXFatemp':
                            print ("   units fix old:", v.units)
                            v.setncattr("units", 'degree_K')
                            print ("   units fix new:", v.units)

                        # fix comments on select variables
                        if minmax_dv in comment_keys:
                            comment_fix_fname = comment_fix[minmax_dv]['filename']

                            # verify filename matches
                            if comment_fix_fname in ecco_filename.name:
                                
                                print("   comment fix", minmax_dv, comment_fix_fname)
                                v.setncattr("comment", comment_fix[minmax_dv]["comments"])
                            else:
                                print("   comment fix: minmax_dv in keys but filename mismatch")
                                return 0
                    else:
                        print(f'{minmax_dv} not in {nc_dvs}')
                   

                # update date of modified metadata
                current_time = datetime.datetime.now().isoformat()[0:19]
                tmp_ds.setncattr('date_modified', current_time)
                tmp_ds.setncattr('date_metadata_modified', current_time)
                #tmp_ds.close()

        print(f"+ SUCCESS: changes applied {ecco_filename.name}\n")
        return 1
    except Exception as e:
        raise e
    
    return 0

# %%
def f1(ecco_files, minmax, comment_fix, qc_prob):
    results = []
    for ecco_filename in ecco_files:
        result = apply_fixes(ecco_filename, minmax, comment_fix, qc_prob)
        results.append(result)
    return results

# %%
def get_groupings(base_dir, grid_type, time_type):
    groupings = dict()
    tmp = Path(f'{base_dir}/{grid_type}/{time_type}')
    print(tmp)
    if tmp.exists():
        g_dirs = np.sort(list(tmp.iterdir()))
        for pi, p in enumerate(g_dirs):
            grouping = str(p).split('/')[-1]
            groupings[pi] = dict()
            groupings[pi]['name'] = grouping
            groupings[pi]['grid'] = grid_type
            groupings[pi]['time_type'] = time_type
            groupings[pi]['directory'] = p
            
    return groupings

# %% [markdown]
# ## Inputs

# %%
grids = ['native','latlon']
time_avgs = ['day_inst', 'day_mean','mon_mean']

# %%
valid_minmax_dir = Path('/home/ifenty/ian1/ifenty/ECCOv4/Version4/Release4/valid_minmax/valid_minmax_final')

# %%
minmax = load_valid_minmax(valid_minmax_dir)
pprint(minmax.keys())
len(minmax.keys())
# Out:
# dict_keys(['ECL5S-SSH44', 'ECL5S-ICO44', 'ECL5S-OTS44', 'ECL5S-OBP44', 'ECL5S-SIV44', 'ECL5D-SIH44', 'ECL5D-OBP44', 'ECL5D-ODE44', 'ECL5D-STF44', 'ECL5D-OML44', 'ECL5D-HEA44', 'ECL5D-ICO44', 'ECL5D-STR44', 'ECL5D-3MT44', 'ECL5D-ATM44', 'ECL5D-BOL44', 'ECL5D-OVE44', 'ECL5D-FRE44', 'ECL5D-SSH44', 'ECL5D-3VF44', 'ECL5D-SIV44', 'ECL5D-OTS44', 'ECL5D-3TF44', 'ECL5D-3SF44', 'ECL5D-ISP44', 'ECL5M-OVE44', 'ECL5M-SIH44', 'ECL5M-ATM44', 'ECL5M-BOL44', 'ECL5M-SIV44', 'ECL5M-ICO44', 'ECL5M-ISP44', 'ECL5M-3VF44', 'ECL5M-3SF44', 'ECL5M-HEA44', 'ECL5M-OBP44', 'ECL5M-3TF44', 'ECL5M-SSH44', 'ECL5M-STR44', 'ECL5M-FRE44', 'ECL5M-OTS44', 'ECL5M-ODE44', 'ECL5M-3MT44', 'ECL5M-OML44', 'ECL5M-STF44', 'ECG5D-HEA44', 'ECG5D-SIV44', 'ECG5D-STR44', 'ECG5D-OBP44', 'ECG5D-OTS44', 'ECG5D-ODE44', 'ECG5D-FRE44', 'ECG5D-OML44', 'ECG5D-SSH44', 'ECG5D-OVE44', 'ECG5D-ATM44', 'ECG5D-ICO44', 'ECG5D-BOL44', 'ECG5M-SIV44', 'ECG5M-ICO44', 'ECG5M-OVE44', 'ECG5M-OTS44', 'ECG5M-OBP44', 'ECG5M-OML44', 'ECG5M-BOL44', 'ECG5M-HEA44', 'ECG5M-ATM44', 'ECG5M-FRE44', 'ECG5M-ODE44', 'ECG5M-STR44', 'ECG5M-SSH44'])
# 71

# %%
dataset_base_dir = Path('/home/ifenty/ian1/ifenty/ECCOv4/Version4/Release4/podaac_test/')

# %%
time_type = time_avgs[2]
grid_type = grids[0]

groupings = get_groupings(dataset_base_dir, grid_type, time_type)
# Out:
# /home/ifenty/ian1/ifenty/ECCOv4/Version4/Release4/podaac_test/native/mon_mean

# %%
for gi in groupings:
    print(gi, groupings[gi]['name'])
# Out:
# 0 ATM_SURFACE_TEMP_HUM_WIND_PRES
# 1 OCEAN_AND_ICE_SURFACE_FW_FLUX
# 2 OCEAN_AND_ICE_SURFACE_HEAT_FLUX
# 3 OCEAN_AND_ICE_SURFACE_STRESS
# 4 OCEAN_BOLUS_VELOCITY
# 5 OCEAN_BOTTOM_PRESSURE
# 6 OCEAN_DENS_STRAT_PRESS
# 7 OCEAN_MIXED_LAYER_DEPTH
# 8 OCEAN_TEMPERATURE_SALINITY
# 9 OCEAN_VELOCITY
# 10 SEA_ICE_CONC_THICKNESS
# 11 SEA_ICE_VELOCITY
# 12 SEA_SURFACE_HEIGHT

# %%
gi = 5
print(groupings[gi])
grouping_info = groupings[gi]
# Out:
# {'name': 'OCEAN_BOTTOM_PRESSURE', 'grid': 'native', 'time_type': 'mon_mean', 'directory': PosixPath('/home/ifenty/ian1/ifenty/ECCOv4/Version4/Release4/podaac_test/native/mon_mean/OCEAN_BOTTOM_PRESSURE')}

# %% [markdown]
# ## Calc

# %%
glob_name = '**/*ECCO_V4r4*nc'
ecco_files = np.sort(list(grouping_info['directory'].glob(glob_name)))
print(len(ecco_files))
ecco_files[0]
# Out:
# 312
# PosixPath('/home/ifenty/ian1/ifenty/ECCOv4/Version4/Release4/podaac_test/native/mon_mean/OCEAN_BOTTOM_PRESSURE/OCEAN_BOTTOM_PRESSURE_mon_mean_1992-01_ECCO_V4r4_latlon_0p50deg.nc')

# %%
ecco_files = ecco_files[0:10]

# %%
qc_prob = 0.01

# %%
start_time = time.time()
f1_out = f1(ecco_files, minmax, comment_fix,qc_prob)
delta_time = time.time() - start_time
time_per = delta_time / len(ecco_files)
# Out:
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1992-01_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1992-02_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1992-03_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1992-04_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1992-05_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1992-06_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1992-07_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1992-08_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1992-09_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1992-10_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1992-11_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1992-12_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1993-01_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1993-02_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1993-03_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1993-04_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1993-05_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1993-06_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1993-07_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1993-08_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1993-09_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1993-10_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1993-11_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1993-12_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1994-01_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1994-02_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1994-03_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1994-04_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
#    QC OBPGMAP
#    QC current dv actual vmin/vmax : 8.28364276886 82.0113601685
#    QC old valid_min/max           : 8.22370624542 82.0854034424
#    QC new valid_min/max           : 8.22370624542 82.0854034424
#    ...old valid min/max was ok
#    ...new valid min/max is ok
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1994-05_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1994-06_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1994-07_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1994-08_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1994-09_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1994-10_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1994-11_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1994-12_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1995-01_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1995-02_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1995-03_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1995-04_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1995-05_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1995-06_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1995-07_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1995-08_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1995-09_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1995-10_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1995-11_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1995-12_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1996-01_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1996-02_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1996-03_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1996-04_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1996-05_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1996-06_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1996-07_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1996-08_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1996-09_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1996-10_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1996-11_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1996-12_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1997-01_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1997-02_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1997-03_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1997-04_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1997-05_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1997-06_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1997-07_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1997-08_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1997-09_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1997-10_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1997-11_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1997-12_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1998-01_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1998-02_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1998-03_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1998-04_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1998-05_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1998-06_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1998-07_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1998-08_ECCO_V4r4_latlon_0p50deg.nc
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1998-09_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1998-10_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1998-11_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1998-12_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1999-01_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1999-02_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1999-03_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1999-04_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1999-05_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1999-06_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1999-07_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1999-08_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1999-09_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1999-10_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1999-11_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_1999-12_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2000-01_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2000-02_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2000-03_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2000-04_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2000-05_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2000-06_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2000-07_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2000-08_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
#    QC OBP
#    QC current dv actual vmin/vmax : -1.72954070568 72.0215911865
#    QC old valid_min/max           : -1.78991889954 72.0701141357
#    QC new valid_min/max           : -1.78991889954 72.0701141357
#    ...old valid min/max was ok
#    ...new valid min/max is ok
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2000-09_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2000-10_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2000-11_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2000-12_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2001-01_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2001-02_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2001-03_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
#    QC OBP
#    QC current dv actual vmin/vmax : -1.77340960503 71.9947509766
#    QC old valid_min/max           : -1.78991889954 72.0701141357
#    QC new valid_min/max           : -1.78991889954 72.0701141357
#    ...old valid min/max was ok
#    ...new valid min/max is ok
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2001-04_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2001-05_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2001-06_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2001-07_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2001-08_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2001-09_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2001-10_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2001-11_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2001-12_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2002-01_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2002-02_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2002-03_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2002-04_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2002-05_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2002-06_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2002-07_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2002-08_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2002-09_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2002-10_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2002-11_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2002-12_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2003-01_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2003-02_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2003-03_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2003-04_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2003-05_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2003-06_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2003-07_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2003-08_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2003-09_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2003-10_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2003-11_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2003-12_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2004-01_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2004-02_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2004-03_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2004-04_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2004-05_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2004-06_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2004-07_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2004-08_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2004-09_ECCO_V4r4_latlon_0p50deg.nc
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2004-10_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2004-11_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2004-12_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2005-01_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2005-02_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2005-03_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2005-04_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2005-05_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2005-06_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2005-07_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2005-08_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2005-09_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2005-10_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2005-11_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
#    QC OBP
#    QC current dv actual vmin/vmax : -1.73800897598 72.0225830078
#    QC old valid_min/max           : -1.78991889954 72.0701141357
#    QC new valid_min/max           : -1.78991889954 72.0701141357
#    ...old valid min/max was ok
#    ...new valid min/max is ok
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2005-12_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2006-01_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2006-02_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2006-03_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2006-04_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2006-05_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2006-06_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2006-07_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2006-08_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2006-09_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2006-10_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2006-11_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2006-12_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2007-01_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2007-02_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2007-03_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2007-04_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2007-05_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2007-06_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2007-07_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2007-08_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2007-09_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2007-10_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2007-11_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2007-12_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2008-01_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2008-02_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2008-03_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
#    QC OBP
#    QC current dv actual vmin/vmax : -1.71544086933 71.9909515381
#    QC old valid_min/max           : -1.78991889954 72.0701141357
#    QC new valid_min/max           : -1.78991889954 72.0701141357
#    ...old valid min/max was ok
#    ...new valid min/max is ok
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2008-04_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2008-05_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2008-06_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2008-07_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2008-08_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2008-09_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2008-10_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2008-11_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2008-12_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2009-01_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2009-02_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2009-03_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2009-04_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2009-05_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2009-06_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2009-07_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2009-08_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2009-09_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2009-10_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2009-11_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2009-12_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2010-01_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2010-02_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2010-03_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2010-04_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2010-05_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2010-06_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2010-07_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2010-08_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2010-09_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2010-10_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2010-11_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2010-12_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2011-01_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2011-02_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2011-03_ECCO_V4r4_latlon_0p50deg.nc
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2011-04_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2011-05_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2011-06_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2011-07_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2011-08_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2011-09_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2011-10_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2011-11_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2011-12_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2012-01_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2012-02_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2012-03_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2012-04_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2012-05_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
#    QC OBP
#    QC current dv actual vmin/vmax : -1.74267566204 71.9909286499
#    QC old valid_min/max           : -178.991882324 7207.01171875
#    QC new valid_min/max           : -1.78991889954 72.0701141357
#    ...old valid min/max was ok
#    ...new valid min/max is ok
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2012-06_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2012-07_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2012-08_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2012-09_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2012-10_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2012-11_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2012-12_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2013-01_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2013-02_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2013-03_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2013-04_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2013-05_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2013-06_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2013-07_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2013-08_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2013-09_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2013-10_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2013-11_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2013-12_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2014-01_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2014-02_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2014-03_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2014-04_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2014-05_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2014-06_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2014-07_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2014-08_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2014-09_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2014-10_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2014-11_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2014-12_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2015-01_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2015-02_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2015-03_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2015-04_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2015-05_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2015-06_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2015-07_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2015-08_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2015-09_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2015-10_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2015-11_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2015-12_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2016-01_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2016-02_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2016-03_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2016-04_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2016-05_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2016-06_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2016-07_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2016-08_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2016-09_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2016-10_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2016-11_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2016-12_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2017-01_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2017-02_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2017-03_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2017-04_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2017-05_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2017-06_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2017-07_ECCO_V4r4_latlon_0p50deg.nc
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2017-08_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2017-09_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2017-10_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2017-11_ECCO_V4r4_latlon_0p50deg.nc
#
# ECG5M-OBP44
# + SUCCESS: changes applied OCEAN_BOTTOM_PRESSURE_mon_mean_2017-12_ECCO_V4r4_latlon_0p50deg.nc

# %%
np.unique(f1_out)
# Out:
# array([1])

# %%
print(delta_time)
print(time_per)
print(time_per*9000)
# Out:
# 5.244294881820679
# 0.016808637441732943
# 151.2777369755965

# %%
ecco_field = xr.open_dataset(ecco_files[0])
ecco_field.close()
shortname = ecco_field.attrs['id'].split('/')[1]
list(ecco_field.data_vars)
print(shortname)
# Out:
# ECG5M-OBP44

# %%
for dv in ecco_field.data_vars:
    print(dv)
    pprint(ecco_field[dv].attrs)
    print('\n')
    pprint(minmax[shortname][dv])
    print('\n\n')
# Out:
# OBP
# {'comment': 'OBP excludes the contribution from global mean atmospheric '
#             'pressure and is therefore suitable for comparisons with GRACE '
#             'data products. OBP is calculated as follows. First, we calculate '
#             'ocean hydrostatic bottom pressure anomaly, PHIBOT, with PHIBOT = '
#             'p_b/rhoConst - gH(t), where p_b = model ocean hydrostatic bottom '
#             'pressure, rhoConst = reference density (1029 kg m-3), g is '
#             'acceleration due to gravity (9.81 m s-2), and H(t) is model depth '
#             'at time t. Then, OBP = PHIBOT/g + corrections for i) global mean '
#             'steric sea level changes related to density changes in the '
#             'Boussinesq volume-conserving model (Greatbatch correction, see '
#             'sterGloH) and ii) global mean atmospheric pressure variations. '
#             'Use OBP for comparisons with ocean bottom pressure data products '
#             'that have been corrected for global mean atmospheric pressure '
#             'variations. GRACE data typically ARE corrected for global mean '
#             'atmospheric pressure variations. In contrast, ocean bottom '
#             'pressure gauge data typically ARE NOT corrected for global mean '
#             'atmospheric pressure variations.',
#  'coverage_content_type': 'modelResult',
#  'long_name': 'Ocean bottom pressure given as equivalent water thickness',
#  'units': 'm',
#  'valid_max': 72.07011413574219,
#  'valid_min': -1.7899188995361328}
#
#
# {'valid_max': 72.07011413574219, 'valid_min': -1.7899188995361328}
#
#
#
# OBPGMAP
# {'comment': 'OBPGMAP includes the contribution from global mean atmospheric '
#             'pressure and is therefore suitable for comparisons with ocean '
#             'bottom pressure gauge data products. OBPGMAP is calculated as '
#             'follows. First, we calculate ocean hydrostatic bottom pressure '
#             'anomaly, PHIBOT, with PHIBOT = p_b/rhoConst - gH(t), where p_b = '
#             'model ocean hydrostatic bottom pressure, rhoConst = reference '
#             'density (1029 kg m-3), g is acceleration due to gravity (9.81 m '
#             's-2), and H(t) is model depth at time t. Then, OBPGMAP= PHIBOT/g '
#             '+ corrections for global mean steric sea level changes related to '
#             'density changes in the Boussinesq volume-conserving model '
#             '(Greatbatch correction, see sterGloH). Use OBPGMAP for '
#             'comparisons with ocean bottom pressure data products that have '
#             'NOT been corrected for global mean atmospheric pressure '
#             'variations. GRACE data typically ARE corrected for global mean '
#             'atmospheric pressure variations. In contrast, ocean bottom '
#             'pressure gauge data typically ARE NOT corrected for global mean '
#             'atmospheric pressure variations.',
#  'coverage_content_type': 'modelResult',
#  'long_name': 'Ocean bottom pressure given as equivalent water thickness, '
#               'includes global mean atmospheric pressure',
#  'units': 'm',
#  'valid_max': 82.08540344238281,
#  'valid_min': 8.223706245422363}
#
#
# {'valid_max': 82.08540344238281, 'valid_min': 8.223706245422363}

# %%
sn = ecco_field.attrs['id'].split('/')[1]
print(sn)
for dv in ecco_field.data_vars:
    print('\t',dv, ecco_field[dv].attrs['units'])
    print('\t ef:',ecco_field[dv].attrs['valid_min'], ecco_field[dv].attrs['valid_max'])
    print('\t mm:',minmax[sn][dv]['valid_min'], minmax[sn][dv]['valid_max'])
# Out:
# ECG5M-OBP44
# 	 OBP m
# 	 ef: -1.7899188995361328 72.07011413574219
# 	 mm: -1.7899188995361328 72.07011413574219
# 	 OBPGMAP m
# 	 ef: 8.223706245422363 82.08540344238281
# 	 mm: 8.223706245422363 82.08540344238281

# %%
ecco_field.attrs
# Out:
# {'acknowledgement': 'This research was carried out by the Jet Propulsion Laboratory, managed by the California Institute of Technology under a contract with the National Aeronautics and Space Administration.',
#  'author': 'Ian Fenty and Ou Wang',
#  'cdm_data_type': 'Grid',
#  'comment': 'Fields provided on a regular lat-lon grid. They have been mapped to the regular lat-lon grid from the original ECCO lat-lon-cap 90 (llc90) native model grid. Ocean bottom pressure given in equivalent water thickness excluding (OBP) and including (OBPGMAP) the contribution from global mean atmospheric pressure.',
#  'Conventions': 'CF-1.8, ACDD-1.3',
#  'creator_email': 'ecco-group@mit.edu',
#  'creator_institution': 'NASA Jet Propulsion Laboratory (JPL)',
#  'creator_name': 'ECCO Consortium',
#  'creator_type': 'group',
#  'creator_url': 'https://ecco-group.org',
#  'date_created': '2020-12-18T09:40:36',
#  'date_issued': '2020-12-18T09:40:36',
#  'geospatial_bounds_crs': 'EPSG:4326',
#  'geospatial_lat_max': 90.0,
#  'geospatial_lat_min': -90.0,
#  'geospatial_lat_resolution': 0.5,
#  'geospatial_lat_units': 'degrees_north',
#  'geospatial_lon_max': 180.0,
#  'geospatial_lon_min': -180.0,
#  'geospatial_lon_resolution': 0.5,
#  'geospatial_lon_units': 'degrees_east',
#  'history': 'Inaugural release of an ECCO Central Estimate solution to PO.DAAC',
#  'id': '10.5067/ECG5M-OBP44',
#  'institution': 'NASA Jet Propulsion Laboratory (JPL)',
#  'instrument_vocabulary': 'GCMD instrument keywords',
#  'keywords': 'EARTH SCIENCE > OCEANS > OCEAN PRESSURE > WATER PRESSURE, EARTH SCIENCE > OCEANS > OCEAN PRESSURE, EARTH SCIENCE SERVICES > MODELS > EARTH SCIENCE REANALYSES/ASSIMILATION MODELS',
#  'keywords_vocabulary': 'NASA Global Change Master Directory (GCMD) Science Keywords',
#  'license': 'Public Domain',
#  'metadata_link': 'https://cmr.earthdata.nasa.gov/search/collections.umm_json?ShortName=ECCO_L4_OBP_05DEG_MONTHLY_V4R4',
#  'naming_authority': 'gov.nasa.jpl',
#  'platform': 'ERS-1/2, TOPEX/Poseidon, Geosat Follow-On (GFO), ENVISAT, Jason-1, Jason-2, CryoSat-2, SARAL/AltiKa, Jason-3, AVHRR, Aquarius, SSM/I, SSMIS, GRACE, DTU17MDT, Argo, WOCE, GO-SHIP, MEOP, Ice Tethered Profilers (ITP)',
#  'platform_vocabulary': 'GCMD platform keywords',
#  'processing_level': 'L4',
#  'product_name': 'OCEAN_BOTTOM_PRESSURE_mon_mean_1992-01_ECCO_V4r4_latlon_0p50deg.nc',
#  'product_time_coverage_end': '2018-01-01T00:00:00',
#  'product_time_coverage_start': '1992-01-01T12:00:00',
#  'product_version': 'Version 4, Release 4',
#  'program': 'NASA Physical Oceanography, Cryosphere, Modeling, Analysis, and Prediction (MAP)',
#  'project': 'Estimating the Circulation and Climate of the Ocean (ECCO)',
#  'publisher_email': 'podaac@podaac.jpl.nasa.gov',
#  'publisher_institution': 'PO.DAAC',
#  'publisher_name': 'Physical Oceanography Distributed Active Archive Center (PO.DAAC)',
#  'publisher_type': 'institution',
#  'publisher_url': 'https://podaac.jpl.nasa.gov',
#  'references': 'ECCO Consortium, Fukumori, I., Wang, O., Fenty, I., Forget, G., Heimbach, P., & Ponte, R. M. 2020. Synopsis of the ECCO Central Production Global Ocean and Sea-Ice State Estimate (Version 4 Release 4). doi:10.5281/zenodo.3765929',
#  'source': 'The ECCO V4r4 state estimate was produced by fitting a free-running solution of the MITgcm (checkpoint 66g) to satellite and in situ observational data in a least squares sense using the adjoint method. https://ecco-group.org/docs/v4r4_synopsis.pdf',
#  'standard_name_vocabulary': 'NetCDF Climate and Forecast (CF) Metadata Convention',
#  'summary': 'This dataset contains monthly-averaged ocean bottom pressure interpolated to a regular 0.5-degree grid from the ECCO Version 4 revision 4 (V4r4) ocean and sea-ice state estimate. Estimating the Circulation and Climate of the Ocean (ECCO) ocean and sea-ice state estimates are dynamically and kinematically-consistent reconstructions of the three-dimensional, time-evolving ocean, sea-ice, and surface atmospheric states. ECCO V4r4 is a free-running solution of the 1-degree global configuration of the MIT general circulation model (MITgcm) that has been fit to observations in a least-squares sense. Observational data constraints used in V4r4 include sea surface height (SSH) from satellite altimeters [ERS-1/2, TOPEX/Poseidon, GFO, ENVISAT, Jason-1,2,3, CryoSat-2, and SARAL/AltiKa]; sea surface temperature (SST) from satellite radiometers [AVHRR], sea surface salinity (SSS) from the Aquarius satellite radiometer/scatterometer, ocean bottom pressure (OBP) from the GRACE satellite gravimeter; sea ice concentration from satellite radiometers [SSM/I and SSMIS], and in-situ ocean temperature and salinity measured with conductivity-temperature-depth (CTD) sensors and expendable bathythermographs (XBTs) from several programs [e.g., WOCE, GO-SHIP, Argo, and others] and platforms [e.g., research vessels, gliders, moorings, ice-tethered profilers, and instrumented pinnipeds]. V4r4 covers the period 1992-01-01T12:00:00 to 2018-01-01T00:00:00.',
#  'time_coverage_duration': 'P1M',
#  'time_coverage_end': '1992-02-01T00:00:00',
#  'time_coverage_resolution': 'P1M',
#  'time_coverage_start': '1992-01-01T12:00:00',
#  'title': 'ECCO Ocean Bottom Pressure - Monthly Mean 0.5 Degree (Version 4 Release 4)',
#  'uuid': '235f3508-4158-11eb-8e9a-0cc47a3f5813',
#  'coordinates_comment': "Note: the global 'coordinates' attribute descibes auxillary coordinates.",
#  'date_metadata_modified': '2021-03-13T08:48:10',
#  'date_modified': '2021-03-13T08:48:10'}
